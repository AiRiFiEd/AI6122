# %%
import os
directory = os.path.dirname(os.getcwd())
import sys
sys.path.append(directory)

# %%
import lxml
import src.data as data

# %% [markdown]
# # Variables

# %%
DIRECTORY_DATA = os.path.join(directory, 'data')
DIRECTORY_OUTPUT = os.path.join(DIRECTORY_DATA,'01')

# %% [markdown]
# # Parsing Dataset

# %%
dblp = data.DatasetDBLP(directory_output=DIRECTORY_OUTPUT)
filepath = os.path.join(DIRECTORY_DATA, 'dblp.xml')
print(filepath)
dblp.from_file(filepath)

# %%
dblp.parse_data()

# %%
idx = dict(dblp.entities_idx_by_key)

# %%
idx.keys()

# %%
idx['title']

# %%
conferences = [k for k in idx['inproceedings'].keys() if 'sigmod' in k.lower()]

# %%
conferences_idx = []
for k in conferences:
    conferences_idx += idx['inproceedings'][k]

# %%
uid = dblp.uid
with open(os.path.join(DIRECTORY_OUTPUT, 'inproceedings_' + uid + '.pkl'), 'rb') as f:
    entities = pickle.load(f)

# %%
uid = dblp.uid
with open(os.path.join(DIRECTORY_OUTPUT, 'title_' + uid + '.pkl'), 'rb') as f:
    titles = pickle.load(f)

# %%
title = titles[200]

# %%
title

# %%
example = entities[1340364]

# %%
example

# %%
conferences_idx

# %%
len(conferences)

# %%
import pickle
uid = dblp.uid
with open(os.path.join(DIRECTORY_OUTPUT, ('entities_idx_by_tag' + '_' + uid + '.pkl')), 'wb') as f:
    dictionary = dict(dblp.entities_idx_by_tag)
    pickle.dump(dictionary, f)
    
with open(os.path.join(DIRECTORY_OUTPUT, ('entities_idx_by_key' + '_' + uid + '.pkl')), 'wb') as f:
    dictionary = dict(dblp.entities_idx_by_key)
    pickle.dump(dictionary, f)
    
with open(os.path.join(DIRECTORY_OUTPUT, ('attributes_by_tag' + '_' + uid + '.pkl')), 'wb') as f:
    dictionary = dict(dblp.attributes_by_tag)
    pickle.dump(dictionary, f)
    
with open(os.path.join(DIRECTORY_OUTPUT, ('relationships_by_tag' + '_' + uid + '.pkl')), 'wb') as f:
    dictionary = dict(dblp.relationships_by_tag)
    pickle.dump(dictionary, f)

# %% [markdown]
# # Loading Data

# %%
len(dblp.entities_idx_by_tag['article'])

# %%
import datetime

import hashlib


hashlib.sha256(str(datetime.datetime.now().timestamp()).encode('utf-8')).hexdigest()

# %%
0 % 10000

# %% [markdown]
# # Adhoc

# %%
from collections import defaultdict
i = 0
elements = []
titles = []
titles_by_date = defaultdict(list)
all_elements = ['inproceedings']
for event, element in dblp.data:
    if element.tag in all_elements:
        
        if 'sigmod' in element.items()[1][1].lower():
            elements.append(element)
            for sub in element:
                if sub.tag == 'title':
                    t = sub.text
                if sub.tag == 'year':
                    d = sub.text
            titles.append(t)
            titles_by_date[d].append(t)

# %% [markdown]
# # Descriptive

# %% [markdown]
# ### inproceedings count per year

# %%
import pandas as pd

tmp = []
for k, v in titles_by_date.items():
    tmp.append([k, len(v)])
df = pd.DataFrame(tmp, columns=['year', 'count'])
df.sort_values('year', inplace=True)
df.plot.bar('year', 'count')
# Out:
# <Axes: xlabel='year'>

# %% [markdown]
# ### title length statistics by year

# %%
import statistics
import numpy as np
tmp = []
y = []
for k, v in titles_by_date.items():
    lengths = []
    for t in v:
        if not t is None:
            lengths.append(len(t.split(' ')))
    
    tmp.append( {'label': k,'whislo':min(lengths), 'whishi':max(lengths), 'med':statistics.median(lengths), 'q1':np.percentile(lengths, 25), 'q3':np.percentile(lengths, 75)})
    y.append(k)
    
tmp = sorted(tmp, key=lambda x: x['label'])
#df = pd.DataFrame(tmp, columns=['year', 'min', 'max', 'med', '25', '75'])
#df.sort_values('year', inplace=True)
y = sorted(y)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

fig, ax = plt.subplots(1,1)
ax.bxp(tmp, showfliers=False)
ax.set_xticks(ticks=range(1, len(y)+1),labels=y, rotation=90)
# Out:
# [<matplotlib.axis.XTick at 0x244fa12c460>,
#  <matplotlib.axis.XTick at 0x244fa12c490>,
#  <matplotlib.axis.XTick at 0x244f9fc06a0>,
#  <matplotlib.axis.XTick at 0x244f9171090>,
#  <matplotlib.axis.XTick at 0x244f9172ad0>,
#  <matplotlib.axis.XTick at 0x244f91728c0>,
#  <matplotlib.axis.XTick at 0x244f9173bb0>,
#  <matplotlib.axis.XTick at 0x244f9170220>,
#  <matplotlib.axis.XTick at 0x244f91733d0>,
#  <matplotlib.axis.XTick at 0x244f91710c0>,
#  <matplotlib.axis.XTick at 0x244f91707c0>,
#  <matplotlib.axis.XTick at 0x244f913e140>,
#  <matplotlib.axis.XTick at 0x244f913da80>,
#  <matplotlib.axis.XTick at 0x244f913cf70>,
#  <matplotlib.axis.XTick at 0x244f913c520>,
#  <matplotlib.axis.XTick at 0x244f913f640>,
#  <matplotlib.axis.XTick at 0x244f913e980>,
#  <matplotlib.axis.XTick at 0x244f913f970>,
#  <matplotlib.axis.XTick at 0x244f9522ef0>,
#  <matplotlib.axis.XTick at 0x244f913c340>,
#  <matplotlib.axis.XTick at 0x244f9520550>,
#  <matplotlib.axis.XTick at 0x244f95226b0>,
#  <matplotlib.axis.XTick at 0x244f9523c70>,
#  <matplotlib.axis.XTick at 0x244f95212a0>,
#  <matplotlib.axis.XTick at 0x244f9520a00>,
#  <matplotlib.axis.XTick at 0x244f9520310>,
#  <matplotlib.axis.XTick at 0x244f54dcfa0>,
#  <matplotlib.axis.XTick at 0x244f54dc310>,
#  <matplotlib.axis.XTick at 0x244f5573c10>,
#  <matplotlib.axis.XTick at 0x244f54def20>,
#  <matplotlib.axis.XTick at 0x244f9171570>,
#  <matplotlib.axis.XTick at 0x244f5571e40>,
#  <matplotlib.axis.XTick at 0x244f55372b0>,
#  <matplotlib.axis.XTick at 0x244f5535d80>,
#  <matplotlib.axis.XTick at 0x244f9521c30>,
#  <matplotlib.axis.XTick at 0x244f5534130>,
#  <matplotlib.axis.XTick at 0x244f906abf0>,
#  <matplotlib.axis.XTick at 0x244f9080670>,
#  <matplotlib.axis.XTick at 0x244f9082560>,
#  <matplotlib.axis.XTick at 0x244f91f98a0>,
#  <matplotlib.axis.XTick at 0x244f918b4f0>,
#  <matplotlib.axis.XTick at 0x244f918a470>,
#  <matplotlib.axis.XTick at 0x244f918a230>,
#  <matplotlib.axis.XTick at 0x244f918aa70>,
#  <matplotlib.axis.XTick at 0x244f9189450>,
#  <matplotlib.axis.XTick at 0x244f9188100>,
#  <matplotlib.axis.XTick at 0x244f9189cf0>,
#  <matplotlib.axis.XTick at 0x244f925efe0>,
#  <matplotlib.axis.XTick at 0x244f918bbe0>,
#  <matplotlib.axis.XTick at 0x244f925de70>,
#  <matplotlib.axis.XTick at 0x244f925d870>,
#  <matplotlib.axis.XTick at 0x244f7c27d90>,
#  <matplotlib.axis.XTick at 0x244f7c25e10>]

# %% [markdown]
# ### tokenize titles and remove stop words

# %%
titles[:10]
# Out:
# ['Bao: Making Learned Query Optimization Practical.',
#  'Comments on Advantages of the Data-Structure-Set-Model.',
#  'DB4ML - An In-Memory Database Kernel with Machine Learning Support.',
#  'Generalized scale independence through incremental precomputation.',
#  'Dynamically optimizing queries over large scale data platforms.',
#  'Time-parameterized queries in spatio-temporal databases.',
#  'SuperSQL: An Extended SQL for Database Publishing and Presentation.',
#  'Event processing with an oracle database.',
#  'Skew handling techniques in sort-merge join.',
#  'Pinot: Realtime OLAP for 530 Million Users.']

# %%
import nltk
from nltk import word_tokenize
from nltk.corpus import stopwords
from nltk.tokenize.treebank import TreebankWordDetokenizer
from nltk.util import ngrams

nltk.download('punkt')
nltk.download('stopwords')
nltk.download('averaged_perceptron_tagger')
import string
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger.zip.

# %% [markdown]
# ### top 10 unigrams

# %%
sw = set(stopwords.words("english") + list(string.punctuation))
counts = defaultdict(lambda:defaultdict(int))
for k, v in titles_by_date.items():
    for t in v:
        if t:
            tokens = [word for word in word_tokenize(t) if not word in sw]
            for tok in tokens:
                counts[k][tok] += 1

# %%
topten = dict()
for k, v in counts.items():
    _ = [[k,v] for k,v in v.items()]
    _ = sorted(_,key=lambda x: x[1],reverse=True)
    top = _[:10]
    topten[k] = top

# %%
topten
# Out:
# {'2021': [['Data', 67],
#   ['A', 48],
#   ['Learning', 26],
#   ['Graph', 25],
#   ['Queries', 20],
#   ['Query', 16],
#   ['Efficient', 16],
#   ['Systems', 15],
#   ['Graphs', 15],
#   ['Distributed', 14]],
#  '1974': [['Data', 24],
#   ['A', 12],
#   ['Base', 8],
#   ['Relational', 7],
#   ['Management', 5],
#   ['System', 5],
#   ['The', 5],
#   ['File', 4],
#   ['Translation', 3],
#   ['Model', 3]],
#  '2020': [['Data', 68],
#   ['A', 41],
#   ['Queries', 26],
#   ['Learning', 25],
#   ['Database', 20],
#   ['Graph', 19],
#   ['Query', 17],
#   ['Search', 16],
#   ['System', 16],
#   ['Analysis', 13]],
#  '2013': [['data', 59],
#   ['graph', 18],
#   ['query', 16],
#   ['using', 14],
#   ['processing', 14],
#   ['system', 14],
#   ['database', 12],
#   ['queries', 12],
#   ['analytics', 11],
#   ['big', 11]],
#  '2014': [['data', 53],
#   ['query', 21],
#   ['queries', 17],
#   ['Data', 17],
#   ['A', 15],
#   ['processing', 15],
#   ['databases', 13],
#   ['graphs', 12],
#   ['Graph', 10],
#   ['using', 10]],
#  '2002': [['data', 20],
#   ['queries', 11],
#   ['database', 11],
#   ['XML', 9],
#   ['query', 6],
#   ['caching', 6],
#   ['databases', 5],
#   ['web', 5],
#   ['Efficient', 5],
#   ['search', 4]],
#  '1998': [['Data', 14],
#   ['Database', 12],
#   ['A', 11],
#   ['System', 10],
#   ['Mining', 9],
#   ['Query', 8],
#   ['Management', 7],
#   ['Databases', 7],
#   ['The', 7],
#   ['Queries', 7]],
#  '2005': [['Data', 14],
#   ['XML', 13],
#   ['A', 12],
#   ['data', 10],
#   ['SQL', 9],
#   ['Efficient', 7],
#   ['Relational', 7],
#   ['system', 7],
#   ['Queries', 6],
#   ['processing', 5]],
#  '2018': [['Data', 54],
#   ['A', 43],
#   ['Query', 24],
#   ['Database', 20],
#   ['Learning', 18],
#   ['Systems', 16],
#   ['Processing', 15],
#   ['System', 13],
#   ['Interactive', 11],
#   ['using', 11]],
#  '2017': [['Data', 49],
#   ['A', 39],
#   ['Query', 15],
#   ['Graph', 14],
#   ['Interactive', 13],
#   ['Learning', 12],
#   ['Processing', 11],
#   ['Database', 11],
#   ['Queries', 11],
#   ['Systems', 10]],
#  '1991': [['Objects', 10],
#   ['A', 9],
#   ['Database', 8],
#   ['An', 7],
#   ['Databases', 6],
#   ['Data', 5],
#   ['Distributed', 4],
#   ['Language', 4],
#   ['Deductive', 4],
#   ['Evaluation', 4]],
#  '2006': [['data', 13],
#   ['query', 11],
#   ['search', 10],
#   ['processing', 8],
#   ['database', 8],
#   ['databases', 7],
#   ['web', 7],
#   ['queries', 5],
#   ['applications', 5],
#   ['management', 5]],
#  '2007': [['data', 27],
#   ['databases', 12],
#   ['database', 11],
#   ['query', 10],
#   ['processing', 10],
#   ['relational', 8],
#   ['using', 8],
#   ['streams', 8],
#   ['efficient', 6],
#   ['management', 6]],
#  '2016': [['Data', 49],
#   ['A', 23],
#   ['data', 22],
#   ['Query', 20],
#   ['Processing', 15],
#   ['Graph', 14],
#   ['Hybrid', 11],
#   ['exploration', 11],
#   ['using', 10],
#   ['Systems', 10]],
#  '1988': [['A', 21],
#   ['Database', 18],
#   ['Data', 13],
#   ['System', 7],
#   ['Relational', 7],
#   ['Object-Oriented', 7],
#   ['Model', 6],
#   ['Systems', 6],
#   ['Databases', 5],
#   ['Management', 5]],
#  '2023': [['Data', 29],
#   ['Workshop', 10],
#   ['Learning', 8],
#   ['Database', 6],
#   ['A', 6],
#   ['Management', 6],
#   ['Systems', 5],
#   ['Education', 5],
#   ['System', 5],
#   ['Demonstration', 5]],
#  '1976': [['Data', 11],
#   ['A', 8],
#   ['Base', 6],
#   ['System', 5],
#   ['Application', 4],
#   ['Abstract', 4],
#   ['Model', 3],
#   ['An', 3],
#   ['Relational', 3],
#   ['Files', 3]],
#  '1990': [['A', 14],
#   ['The', 10],
#   ['Database', 9],
#   ['System', 7],
#   ['Query', 6],
#   ['Systems', 4],
#   ['Management', 4],
#   ['Interface', 4],
#   ['Data', 4],
#   ['Processing', 3]],
#  '2001': [['Data', 20],
#   ['A', 14],
#   ['Queries', 10],
#   ['System', 7],
#   ['Efficient', 7],
#   ['Web', 7],
#   ['Optimization', 6],
#   ['Management', 6],
#   ['XML', 6],
#   ['Dynamic', 6]],
#  '2022': [['Data', 42],
#   ['A', 32],
#   ['Query', 21],
#   ['Efficient', 19],
#   ['Learning', 19],
#   ['Database', 17],
#   ['Systems', 16],
#   ['Queries', 15],
#   ['Management', 13],
#   ['An', 11]],
#  '2009': [['data', 25],
#   ['databases', 14],
#   ['query', 12],
#   ['search', 12],
#   ['database', 11],
#   ['A', 10],
#   ['using', 9],
#   ['web', 8],
#   ['applications', 7],
#   ['queries', 7]],
#  '2015': [['Data', 52],
#   ['A', 25],
#   ['Query', 19],
#   ['Processing', 18],
#   ['An', 17],
#   ['Database', 14],
#   ['Efficient', 13],
#   ['Distributed', 12],
#   ['Databases', 12],
#   ['System', 12]],
#  '1999': [['Data', 18],
#   ['Databases', 12],
#   ['A', 10],
#   ['Query', 9],
#   ['The', 9],
#   ['System', 8],
#   ['Database', 7],
#   ['Web', 7],
#   ['Information', 6],
#   ['Management', 6]],
#  '2004': [['Data', 21],
#   ['Query', 17],
#   ['Database', 15],
#   ['XML', 13],
#   ['Web', 13],
#   ['Queries', 11],
#   ['A', 10],
#   ['Processing', 9],
#   ['An', 9],
#   ['Efficient', 8]],
#  '1981': [['Database', 7],
#   ['A', 4],
#   ['Data', 4],
#   ['Distributed', 4],
#   ['Using', 3],
#   ['The', 3],
#   ['For', 3],
#   ['Systems', 2],
#   ['On', 2],
#   ['Evaluation', 2]],
#  '1996': [['A', 11],
#   ['Data', 10],
#   ['Databases', 8],
#   ['Optimization', 7],
#   ['Query', 6],
#   ['Techniques', 6],
#   ['Database', 5],
#   ['System', 5],
#   ['Queries', 5],
#   ['Systems', 4]],
#  '1997': [['Data', 16],
#   ['Database', 10],
#   ['The', 8],
#   ['A', 7],
#   ['System', 7],
#   ['An', 6],
#   ['Rules', 6],
#   ['Maintenance', 5],
#   ['Queries', 5],
#   ['Systems', 5]],
#  '2019': [['Data', 60],
#   ['A', 32],
#   ['Learning', 20],
#   ['Query', 16],
#   ['Graph', 15],
#   ['Queries', 13],
#   ['Analytics', 12],
#   ['System', 12],
#   ['Database', 12],
#   ['Big', 11]],
#  '2010': [['data', 34],
#   ['query', 14],
#   ['search', 13],
#   ['processing', 11],
#   ['databases', 11],
#   ['database', 10],
#   ['system', 10],
#   ['queries', 9],
#   ['using', 8],
#   ['information', 7]],
#  '2008': [['data', 27],
#   ['database', 14],
#   ['system', 11],
#   ['databases', 11],
#   ['query', 11],
#   ['queries', 10],
#   ['Efficient', 9],
#   ['search', 8],
#   ['systems', 7],
#   ['uncertain', 6]],
#  '2012': [['data', 25],
#   ['large', 14],
#   ['search', 13],
#   ['database', 11],
#   ['graphs', 9],
#   ['query', 9],
#   ['processing', 9],
#   ['queries', 9],
#   ['abstract', 8],
#   ['management', 8]],
#  '1978': [['A', 12],
#   ['Data', 11],
#   ['Database', 10],
#   ['Distributed', 5],
#   ['Relational', 5],
#   ['Base', 5],
#   ['Databases', 5],
#   ['Access', 4],
#   ['Applications', 4],
#   ['An', 4]],
#  '1994': [['A', 18],
#   ['Database', 17],
#   ['Data', 9],
#   ['System', 8],
#   ['Object', 7],
#   ['Query', 7],
#   ['The', 7],
#   ['Object-Oriented', 6],
#   ['Processing', 6],
#   ['Databases', 5]],
#  '1980': [['Data', 35],
#   ['A', 26],
#   ['Database', 24],
#   ['Modelling', 10],
#   ['Design', 9],
#   ['Types', 9],
#   ['System', 9],
#   ['Bases', 8],
#   ['discussion', 8],
#   ['Base', 8]],
#  '1983': [['Database', 27],
#   ['A', 17],
#   ['Design', 12],
#   ['Data', 11],
#   ['Databases', 8],
#   ['DBMS', 7],
#   ['An', 7],
#   ['Management', 7],
#   ['Relational', 6],
#   ['Abstract', 5]],
#  '2000': [['Data', 17],
#   ['A', 17],
#   ['System', 11],
#   ['Mining', 10],
#   ['Databases', 10],
#   ['Query', 8],
#   ['Queries', 7],
#   ['Database', 7],
#   ['An', 7],
#   ['Efficient', 6]],
#  '1975': [['Data', 30],
#   ['Design', 16],
#   ['Base', 13],
#   ['A', 12],
#   ['System', 9],
#   ['Computer', 6],
#   ['Structures', 6],
#   ['Bases', 5],
#   ['Management', 5],
#   ['Approach', 5]],
#  '1971': [['Data', 13],
#   ['A', 6],
#   ['Base', 5],
#   ['Storage', 3],
#   ['File', 3],
#   ['Access', 3],
#   ['Management', 2],
#   ['Table', 2],
#   ['Retrieval', 2],
#   ['Relational', 2]],
#  '2003': [['Data', 27],
#   ['A', 21],
#   ['XML', 17],
#   ['Query', 9],
#   ['Processing', 8],
#   ['Databases', 7],
#   ['Efficient', 7],
#   ['Queries', 7],
#   ['Database', 6],
#   ['System', 6]],
#  '2011': [['data', 33],
#   ['search', 15],
#   ['query', 14],
#   ['databases', 10],
#   ['queries', 10],
#   ['processing', 9],
#   ['system', 9],
#   ['analysis', 8],
#   ['efficient', 8],
#   ['A', 8]],
#  '1986': [['Database', 12],
#   ['A', 7],
#   ['Query', 6],
#   ['Evaluation', 5],
#   ['Management', 5],
#   ['Systems', 5],
#   ['System', 5],
#   ['Approach', 4],
#   ['Processing', 4],
#   ['Applications', 3]],
#  '1992': [['A', 12],
#   ['Database', 11],
#   ['Databases', 9],
#   ['System', 8],
#   ['Performance', 8],
#   ['Query', 7],
#   ['Data', 6],
#   ['Object-Oriented', 6],
#   ['The', 6],
#   ['Concurrency', 5]],
#  '1995': [['System', 15],
#   ['The', 14],
#   ['A', 13],
#   ['Database', 13],
#   ['Databases', 8],
#   ['Query', 8],
#   ['An', 5],
#   ['Systems', 5],
#   ['Active', 4],
#   ['Indexing', 4]],
#  '1972': [['Data', 14],
#   ['An', 6],
#   ['A', 5],
#   ['Translation', 4],
#   ['Definition', 4],
#   ['Model', 3],
#   ['Approach', 3],
#   ['Independent', 3],
#   ['Its', 3],
#   ['Trees', 2]],
#  '1982': [['Database', 15],
#   ['A', 11],
#   ['Query', 10],
#   ['Data', 8],
#   ['Management', 7],
#   ['Relational', 6],
#   ['System', 5],
#   ['Language', 4],
#   ['Systems', 3],
#   ['The', 3]],
#  '1993': [['Database', 18],
#   ['A', 14],
#   ['System', 14],
#   ['The', 12],
#   ['Databases', 9],
#   ['Data', 9],
#   ['Distributed', 8],
#   ['Systems', 8],
#   ['Object-Oriented', 7],
#   ['Information', 7]],
#  '1989': [['A', 10],
#   ['Databases', 8],
#   ['Data', 8],
#   ['Database', 8],
#   ['Relational', 6],
#   ['Queries', 5],
#   ['Query', 5],
#   ['Performance', 5],
#   ['On', 4],
#   ['Model', 4]],
#  '1977': [['Data', 10],
#   ['A', 9],
#   ['Database', 7],
#   ['An', 7],
#   ['Abstract', 5],
#   ['Base', 4],
#   ['Management', 4],
#   ['Systems', 3],
#   ['Study', 3],
#   ['Language', 3]],
#  '1987': [['Database', 15],
#   ['A', 13],
#   ['System', 8],
#   ['Data', 7],
#   ['Systems', 7],
#   ['The', 7],
#   ['Design', 5],
#   ['Transaction', 5],
#   ['Relational', 4],
#   ['Query', 4]],
#  '1985': [['Database', 14],
#   ['A', 9],
#   ['Systems', 7],
#   ['Databases', 6],
#   ['Design', 5],
#   ['Information', 4],
#   ['Model', 4],
#   ['Panel', 4],
#   ['System', 3],
#   ['Query', 3]],
#  '1979': [['Data', 9],
#   ['Database', 6],
#   ['Relational', 6],
#   ['Management', 4],
#   ['Model', 4],
#   ['The', 3],
#   ['Performance', 3],
#   ['Analysis', 3],
#   ['Base', 3],
#   ['System', 3]],
#  '1984': [['Database', 10],
#   ['System', 7],
#   ['A', 5],
#   ['Relational', 5],
#   ['Using', 4],
#   ['An', 4],
#   ['Performance', 3],
#   ['Evaluation', 3],
#   ['Query', 3],
#   ['Retrieval', 3]],
#  '1970': [['Data', 17],
#   ['pre-discussion', 9],
#   ['summary', 9],
#   ['Storage', 8],
#   ['Structure', 8],
#   ['Definition', 8],
#   ['Language', 7],
#   ['A', 4],
#   ['Task', 3],
#   ['Group', 3]]}

# %% [markdown]
# ### top 10 bigrams

# %%
sw = set(stopwords.words("english") + list(string.punctuation))
counts_bigrams = defaultdict(lambda:defaultdict(int))
for k, v in titles_by_date.items():
    for t in v:
        if t:
            tokens = [word for word in word_tokenize(t) if not word in sw]
            ngs = ngrams(tokens,2)
            for gram in ngs:
                counts_bigrams[k][TreebankWordDetokenizer().detokenize(gram)] += 1

# %%
toptenbigrams = dict()
for k, v in counts_bigrams.items():
    _ = [[k,v] for k,v in v.items()]
    _ = sorted(_,key=lambda x: x[1],reverse=True)
    top = _[:10]
    toptenbigrams[k] = top

# %%
toptenbigrams
# Out:
# {'2021': [['Machine Learning', 10],
#   ['Data Analysis', 4],
#   ['Data Management', 4],
#   ['Learning Systems', 4],
#   ['Differentially Private', 4],
#   ['Cardinality Estimation', 4],
#   ['Query Processing', 4],
#   ['Deep Learning', 4],
#   ['Database Systems', 3],
#   ['Learning Pipelines', 3]],
#  '1974': [['Data Base', 8],
#   ['Relational Data', 4],
#   ['The Relational', 3],
#   ['Data Management', 3],
#   ['Comments Advantages', 2],
#   ['Base Management', 2],
#   ['A Data', 2],
#   ['Data Description', 2],
#   ['Description Language', 2],
#   ['Management System', 2]],
#  '2020': [['Machine Learning', 8],
#   ['A System', 5],
#   ['Interactive Data', 5],
#   ['Big Data', 4],
#   ['Data Analysis', 4],
#   ['A Framework', 4],
#   ['Stream Processing', 4],
#   ['Query Processing', 3],
#   ['Data Lakes', 3],
#   ['Web Data', 3]],
#  '2013': [['big data', 9],
#   ['data streams', 4],
#   ['data management', 4],
#   ['query processing', 3],
#   ['data analytics', 3],
#   ['graph databases', 3],
#   ['social networks', 3],
#   ['data processing', 3],
#   ['large networks', 2],
#   ['large graph', 2]],
#  '2014': [['big data', 7],
#   ['query processing', 7],
#   ['relational databases', 6],
#   ['Big Data', 4],
#   ['queries large', 3],
#   ['large scale', 3],
#   ['Large-Scale Graph', 3],
#   ['social networks', 3],
#   ['similarity search', 3],
#   ['analytical queries', 3]],
#  '2002': [['high dimensional', 2],
#   ['dimensional data', 2],
#   ['XML data', 2],
#   ['query processing', 2],
#   ['pattern queries', 2],
#   ['application servers', 2],
#   ['Database tuning', 2],
#   ['tuning principles', 2],
#   ['principles experiments', 2],
#   ['experiments troubleshooting', 2]],
#  '1998': [['Data Mining', 4],
#   ['Data Access', 3],
#   ['Database Systems', 3],
#   ['Association Rules', 2],
#   ['Management System', 2],
#   ['A System', 2],
#   ['Queries Using', 2],
#   ['Using Queries', 2],
#   ['Queries Based', 2],
#   ['Based Textual', 2]],
#  '2005': [['SQL server', 4],
#   ['microsoft SQL', 3],
#   ['processing oracle', 2],
#   ['Large Video', 2],
#   ['Continuous Queries', 2],
#   ['Stream Mining', 2],
#   ['XML relational', 2],
#   ['relational database', 2],
#   ['database management', 2],
#   ['management systems', 2]],
#  '2018': [['Query Processing', 8],
#   ['Database Systems', 8],
#   ['Machine Learning', 8],
#   ['Data Analysis', 4],
#   ['Knowledge Base', 4],
#   ['Data Management', 4],
#   ['Apache Spark', 3],
#   ['Reinforcement Learning', 3],
#   ['Differential Privacy', 3],
#   ['Data Streams', 3]],
#  '2017': [['Machine Learning', 8],
#   ['Query Processing', 5],
#   ['Approximate Query', 4],
#   ['Data Exploration', 4],
#   ['Data Management', 4],
#   ['Database Systems', 3],
#   ['Entity Matching', 3],
#   ['Extended Abstract', 3],
#   ['FEIII 2017', 3],
#   ['2017 Challenge', 3]],
#  '1991': [['Complex Objects', 3],
#   ['Relational Databases', 2],
#   ['Objects A', 2],
#   ['Data Model', 2],
#   ['Object Bases', 2],
#   ['Deductive Database', 2],
#   ['Database System', 2],
#   ['Heterogeneous Distributed', 2],
#   ['A Retrieval', 1],
#   ['Retrieval Technique', 1]],
#  '2006': [['query processing', 5],
#   ['web applications', 4],
#   ['sensor networks', 3],
#   ['data streams', 3],
#   ['high performance', 2],
#   ['database systems', 2],
#   ['data-driven web', 2],
#   ['data services', 2],
#   ['services platform', 2],
#   ['Data management', 2]],
#  '2007': [['data streams', 4],
#   ['relational databases', 3],
#   ['query processing', 3],
#   ['database systems', 3],
#   ['relational data', 3],
#   ['database management', 2],
#   ['data sources', 2],
#   ['metasearch engine', 2],
#   ['monitoring queries', 2],
#   ['data stream', 2]],
#  '2016': [['Query Processing', 5],
#   ['Data Cleaning', 5],
#   ['Data Management', 4],
#   ['Big Data', 4],
#   ['A Hybrid', 4],
#   ['data exploration', 4],
#   ['Concurrency Control', 3],
#   ['Machine Learning', 3],
#   ['big data', 3],
#   ['Database Systems', 3]],
#  '1988': [['Object-Oriented Database', 4],
#   ['An Object-Oriented', 3],
#   ['Extended Abstract', 3],
#   ['Data Model', 3],
#   ['Performance Analysis', 3],
#   ['Deductive Databases', 2],
#   ['A Relational', 2],
#   ['Relational Database', 2],
#   ['Relational Databases', 2],
#   ['Invited Paper', 2]],
#  '2023': [['Machine Learning', 5],
#   ['Data Management', 4],
#   ['International Workshop', 4],
#   ['Data Analytics', 3],
#   ['Natural Language', 3],
#   ['Workshop Data', 3],
#   ['Knowledge Graphs', 2],
#   ['Data Processing', 2],
#   ['A Demonstration', 2],
#   ['Artificial Intelligence', 2]],
#  '1976': [['Data Base', 6],
#   ['Relational Data', 2],
#   ['Base System', 2],
#   ['System Abstract', 2],
#   ['Structured Data', 2],
#   ['Management System', 2],
#   ['Application Analytical', 1],
#   ['Analytical Model', 1],
#   ['Model Evaluate', 1],
#   ['Evaluate Storage', 1]],
#  '1990': [['A Framework', 2],
#   ['Access Method', 2],
#   ['Graphical Interface', 2],
#   ['Interface Ode', 2],
#   ['Concurrency Control', 2],
#   ['Database Management', 2],
#   ['Database System', 2],
#   ['Data Base', 2],
#   ['System Manifesto', 2],
#   ['Performance Evaluation', 2]],
#  '2001': [['Data Management', 4],
#   ['Time Series', 4],
#   ['Query Optimization', 3],
#   ['Dynamic Content', 3],
#   ['Panel Abstract', 3],
#   ['A System', 2],
#   ['Materialized View', 2],
#   ['High-Dimensional Data', 2],
#   ['Aggregate Queries', 2],
#   ['XML Data', 2]],
#  '2022': [['Machine Learning', 9],
#   ['Data Management', 7],
#   ['International Workshop', 6],
#   ['Query Processing', 4],
#   ['Video Analytics', 4],
#   ['Reinforcement Learning', 4],
#   ['Database Systems', 3],
#   ['Query Optimizer', 3],
#   ['Management Systems', 3],
#   ['Entity Resolution', 3]],
#  '2009': [['nearest neighbor', 3],
#   ['data analysis', 3],
#   ['keyword search', 3],
#   ['query optimization', 2],
#   ['keyword queries', 2],
#   ['Keyword search', 2],
#   ['join processing', 2],
#   ['A comparison', 2],
#   ['data web', 2],
#   ['management system', 2]],
#  '2015': [['Big Data', 10],
#   ['Data Processing', 5],
#   ['Database Systems', 4],
#   ['Non-Volatile Memory', 3],
#   ['Concurrency Control', 3],
#   ['Query Plans', 3],
#   ['Keyword Search', 3],
#   ['Data Cleaning', 3],
#   ['Parallel Database', 3],
#   ['Database System', 3]],
#  '1999': [['Approximate Query', 2],
#   ['Query Answering', 2],
#   ['Web Information', 2],
#   ['Random Sampling', 2],
#   ['Constrained Frequent', 2],
#   ['Frequent Set', 2],
#   ['Set Queries', 2],
#   ['A System', 2],
#   ['Efficient Concurrency', 2],
#   ['Concurrency Control', 2]],
#  '2004': [['Web Services', 6],
#   ['Query Processing', 3],
#   ['Data Streams', 3],
#   ['Continuous Queries', 2],
#   ['Vertical Horizontal', 2],
#   ['Relaxed Currency', 2],
#   ['Currency Consistency', 2],
#   ['An Efficient', 2],
#   ['Data Integration', 2],
#   ['Database Operations', 2]],
#  '1981': [['Distributed Database', 4],
#   ['Database Systems', 2],
#   ['Deadlock Removal', 1],
#   ['Removal Using', 1],
#   ['Using Partial', 1],
#   ['Partial Rollback', 1],
#   ['Rollback Database', 1],
#   ['On Power', 1],
#   ['Power Locking', 1],
#   ['The K-D-B-Tree', 1]],
#  '1996': [['A Query', 2],
#   ['Query Language', 2],
#   ['Optimization Techniques', 2],
#   ['View Maintenance', 2],
#   ['Object-Oriented Databases', 2],
#   ['Data Mining', 2],
#   ['Relational Databases', 2],
#   ['A Content-Based', 2],
#   ['Content-Based Multimedia', 2],
#   ['Multimedia Server', 2]],
#  '1997': [['Database Systems', 5],
#   ['Experience Paper', 5],
#   ['View Maintenance', 3],
#   ['Association Rules', 3],
#   ['Large Datasets', 3],
#   ['Maintenance Data', 2],
#   ['Case Studies', 2],
#   ['Data Mining', 2],
#   ['DEVise Integrated', 2],
#   ['Integrated Querying', 2]],
#  '2019': [['Machine Learning', 10],
#   ['Big Data', 7],
#   ['Data Management', 6],
#   ['Time Series', 5],
#   ['Data Analytics', 5],
#   ['Data Cleaning', 5],
#   ['Large Scale', 4],
#   ['Error Detection', 4],
#   ['International Workshop', 4],
#   ['Stream Processing', 3]],
#  '2010': [['information extraction', 4],
#   ['data integration', 3],
#   ['keyword search', 3],
#   ['probabilistic databases', 3],
#   ['data management', 2],
#   ['graph processing', 2],
#   ['processing cloud', 2],
#   ['query language', 2],
#   ['string similarity', 2],
#   ['uncertain data', 2]],
#  '2008': [['SQL server', 4],
#   ['case study', 3],
#   ['uncertain data', 3],
#   ['microsoft SQL', 3],
#   ['scientific workflows', 2],
#   ['query optimization', 2],
#   ['query processing', 2],
#   ['data streams', 2],
#   ['spatial databases', 2],
#   ['pattern matching', 2]],
#  '2012': [['large graphs', 6],
#   ['keyword search', 6],
#   ['relational databases', 3],
#   ['linked data', 3],
#   ['social media', 3],
#   ['SQL server', 2],
#   ['Managing mining', 2],
#   ['mining large', 2],
#   ['search relational', 2],
#   ['event processing', 2]],
#  '1978': [['Data Base', 5],
#   ['Base Applications', 3],
#   ['Query Processing', 2],
#   ['Access Paths', 2],
#   ['Implementation INDY', 2],
#   ['INDY Backend', 2],
#   ['Backend Kernel', 2],
#   ['Distributed Databases', 2],
#   ['Use Database', 2],
#   ['View Representation', 1]],
#  '1994': [['A System', 4],
#   ['Query Processing', 3],
#   ['Data Replication', 2],
#   ['Object Store', 2],
#   ['Decision Support', 2],
#   ['Object Database', 2],
#   ['Database Management', 2],
#   ['Deductive Database', 2],
#   ['Object-Oriented Database', 2],
#   ['Parallel Database', 2]],
#  '1980': [['Data Base', 8],
#   ['Data Bases', 7],
#   ['Data Types', 5],
#   ['Data Abstraction', 5],
#   ['Programming Language', 4],
#   ['Database Machine', 3],
#   ['Database Management', 3],
#   ['Mass Storage', 3],
#   ['Physical Database', 2],
#   ['Database Design', 2]],
#  '1983': [['Distributed Database', 4],
#   ['Session Overview', 3],
#   ['Database System', 3],
#   ['An Experimental', 3],
#   ['Database Administration', 2],
#   ['Database Support', 2],
#   ['Relational Databases', 2],
#   ['Data Base', 2],
#   ['Relational DBMS', 2],
#   ['Requirements Specification', 2]],
#  '2000': [['Data Mining', 4],
#   ['Panel Abstract', 3],
#   ['Automatic Summary', 2],
#   ['Summary Tables', 2],
#   ['Large Databases', 2],
#   ['Adaptive Query', 2],
#   ['Query Processing', 2],
#   ['MOCHA A', 2],
#   ['Database Middleware', 2],
#   ['Middleware System', 2]],
#  '1975': [['Data Base', 13],
#   ['Data Bases', 5],
#   ['Data Structures', 4],
#   ['A Data', 4],
#   ['Base Management', 3],
#   ['System Design', 3],
#   ['Design Automation', 3],
#   ['Management System', 2],
#   ['Computer Aided', 2],
#   ['Aided Design', 2]],
#  '1971': [['Data Base', 5],
#   ['Data Independence', 2],
#   ['Data Privacy', 2],
#   ['Privacy Integrity', 2],
#   ['A Brief', 2],
#   ['Evolution Data', 1],
#   ['Base Management', 1],
#   ['Management A.O', 1],
#   ['A.O Smith', 1],
#   ['Expandable Open', 1]],
#  '2003': [['Data Streams', 4],
#   ['XML Data', 3],
#   ['Semantic OLAP', 2],
#   ['Querying XML', 2],
#   ['The Future', 2],
#   ['Future Web', 2],
#   ['A System', 2],
#   ['Data Stream', 2],
#   ['Database Caching', 2],
#   ['Query Optimization', 2]],
#  '2011': [['information extraction', 3],
#   ['query processing', 3],
#   ['data management', 3],
#   ['data warehouses', 3],
#   ['similarity search', 3],
#   ['information networks', 2],
#   ['relational databases', 2],
#   ['hidden web', 2],
#   ['flash memory', 2],
#   ['data cubes', 2]],
#  '1986': [['Query Processing', 4],
#   ['Database Management', 3],
#   ['Database System', 3],
#   ['Management Systems', 2],
#   ['Database Systems', 2],
#   ['Performance Evaluation', 2],
#   ['On Evaluation', 1],
#   ['Evaluation Strategy', 1],
#   ['Strategy EDUCE', 1],
#   ['Prefetching Realtime', 1]],
#  '1992': [['Database System', 5],
#   ['Transaction Processing', 3],
#   ['Using Write-Ahead', 2],
#   ['Object-Oriented Databases', 2],
#   ['An Efficient', 2],
#   ['Concurrency Control', 2],
#   ['Data Management', 2],
#   ['High Performance', 2],
#   ['A Database', 2],
#   ['Optimization Object-Oriented', 2]],
#  '1995': [['Database System', 5],
#   ['A System', 3],
#   ['Database Systems', 3],
#   ['Large Databases', 2],
#   ['Query By', 2],
#   ['A Database', 2],
#   ['Object Query', 2],
#   ['Query Languages', 2],
#   ['An Overview', 2],
#   ['Join Queries', 2]],
#  '1972': [['An Approach', 3],
#   ['Data Definition', 3],
#   ['Data Translation', 2],
#   ['Stored Data', 2],
#   ['Definition Translation', 2],
#   ['Data Independent', 2],
#   ['Independent Accessing', 2],
#   ['Accessing Model', 2],
#   ['Data Base', 2],
#   ['A Development', 1]],
#  '1982': [['Database Management', 6],
#   ['Relational Database', 4],
#   ['Query Language', 4],
#   ['Management System', 3],
#   ['Query Processing', 2],
#   ['Data Base', 2],
#   ['Query Optimization', 2],
#   ['Management Panel', 2],
#   ['Fast Methods', 1],
#   ['Methods Testing', 1]],
#  '1993': [['Database System', 6],
#   ['Information Systems', 3],
#   ['Object-Oriented Databases', 2],
#   ['Design Implementation', 2],
#   ['Hash Joins', 2],
#   ['Open OODB', 2],
#   ['Extended Abstract', 2],
#   ['Relational Databases', 2],
#   ['Object Database', 2],
#   ['Management System', 2]],
#  '1989': [['Concurrency Control', 3],
#   ['Relational Model', 2],
#   ['Extended Abstract', 2],
#   ['Object-Oriented DBMS', 2],
#   ['Data Model', 2],
#   ['Efficient Evaluation', 2],
#   ['Evaluating Size', 1],
#   ['Size Queries', 1],
#   ['Queries Relational', 1],
#   ['Relational Databases', 1]],
#  '1977': [['Data Base', 4],
#   ['Data Bases', 3],
#   ['Database Systems', 2],
#   ['A Study', 2],
#   ['Data Management', 2],
#   ['A Practical', 1],
#   ['Practical Deadlock', 1],
#   ['Deadlock Avoidance', 1],
#   ['Avoidance Algorithm', 1],
#   ['Algorithm Data', 1]],
#  '1987': [['Database System', 4],
#   ['Data Management', 3],
#   ['Query Optimization', 3],
#   ['Database Systems', 3],
#   ['Management Systems', 2],
#   ['Recursive Rule', 2],
#   ['Object Oriented', 2],
#   ['Rule Trading', 2],
#   ['Trading Memory', 2],
#   ['Object-Oriented Database', 2]],
#  '1985': [['Database Systems', 4],
#   ['Distributed Database', 3],
#   ['Information System', 2],
#   ['Query Languages', 2],
#   ['Database Management', 2],
#   ['Systems Panel', 2],
#   ['Database Design', 2],
#   ['Information Systems', 2],
#   ['Relational Databases', 2],
#   ['Adaptive Information', 1]],
#  '1979': [['Relational Database', 3],
#   ['Performance Analysis', 3],
#   ['Data Base', 3],
#   ['Base Management', 2],
#   ['Management System', 2],
#   ['Data Model', 2],
#   ['The Data', 1],
#   ['Data Management', 1],
#   ['Management Facilities', 1],
#   ['Facilities PLAIN', 1]],
#  '1984': [['Database Systems', 3],
#   ['Database System', 2],
#   ['Performance Evaluation', 2],
#   ['A Methodology', 1],
#   ['Methodology Database', 1],
#   ['System Performance', 1],
#   ['Optimal Computation', 1],
#   ['Computation Total', 1],
#   ['Total Projections', 1],
#   ['Projections Unions', 1]],
#  '1970': [['pre-discussion summary', 9],
#   ['Storage Structure', 7],
#   ['Structure Definition', 6],
#   ['Definition Language', 5],
#   ['Task Group', 3],
#   ['Data Base', 3],
#   ['Data Description', 2],
#   ['Language SSDL', 2],
#   ['Data Validation', 2],
#   ['Data Definition', 2]]}

# %% [markdown]
# ### top 10 trigrams

# %%
sw = set(stopwords.words("english") + list(string.punctuation))
counts_trigrams = defaultdict(lambda:defaultdict(int))
for k, v in titles_by_date.items():
    for t in v:
        if t:
            tokens = [word for word in word_tokenize(t) if not word in sw]
            ngs = ngrams(tokens,3)
            for gram in ngs:
                counts_trigrams[k][TreebankWordDetokenizer().detokenize(gram)] += 1

# %%
toptentrigrams = dict()
for k, v in counts_trigrams.items():
    _ = [[k,v] for k,v in v.items()]
    _ = sorted(_,key=lambda x: x[1],reverse=True)
    top = _[:10]
    toptentrigrams[k] = top

# %%
toptentrigrams
# Out:
# {'2021': [['Machine Learning Pipelines', 2],
#   ['Exploratory Data Analysis', 2],
#   ['Event Stream Processing', 2],
#   ['An Experimental Study', 2],
#   ['Database Management Systems', 2],
#   ['Graph Convolutional Networks', 2],
#   ['Machine Learning Systems', 2],
#   ['Distributed Machine Learning', 2],
#   ['Machine Learning Training', 2],
#   ['Graph Neural Networks', 2]],
#  '1974': [['Relational Data Management', 3],
#   ['Data Base Management', 2],
#   ['A Data Description', 2],
#   ['Data Description Language', 2],
#   ['Data Management System', 2],
#   ['The Relational Network', 2],
#   ['Relational Network Approaches', 2],
#   ['Title Workshop Committee', 2],
#   ['Workshop Committee Editor', 2],
#   ["Committee Editor's", 2]],
#  '2020': [['Approximate Nearest Neighbor', 2],
#   ['Nearest Neighbor Search', 2],
#   ['Large Directed Graphs', 2],
#   ['Context-Free Path Querying', 2],
#   ['Minimization Classifier Construction', 2],
#   ['Classifier Construction Cost', 2],
#   ['Key-Value Storage Engines', 2],
#   ['Stream Processing Systems', 2],
#   ['Data Analysis via', 2],
#   ['DB4ML An In-Memory', 1]],
#  '2013': [['big data analytics', 3],
#   ['detection dynamic networks', 2],
#   ['Generalized scale independence', 1],
#   ['scale independence incremental', 1],
#   ['independence incremental precomputation', 1],
#   ['Indexing subtree similarity-search', 1],
#   ['subtree similarity-search using', 1],
#   ['similarity-search using edit', 1],
#   ['using edit distance', 1],
#   ['D-Zipfian decentralized implementation', 1]],
#  '2014': [['large dynamic graphs', 3],
#   ['queries graph databases', 2],
#   ['approximate query processing', 2],
#   ['queries large dynamic', 2],
#   ['online social networks', 2],
#   ['Dynamically optimizing queries', 1],
#   ['optimizing queries large', 1],
#   ['queries large scale', 1],
#   ['large scale data', 1],
#   ['scale data platforms', 1]],
#  '2002': [['high dimensional data', 2],
#   ['Database tuning principles', 2],
#   ['tuning principles experiments', 2],
#   ['principles experiments troubleshooting', 2],
#   ['experiments troubleshooting techniques', 2],
#   ['troubleshooting techniques part', 2],
#   ['Time-parameterized queries spatio-temporal', 1],
#   ['queries spatio-temporal databases', 1],
#   ['Skew handling techniques', 1],
#   ['handling techniques sort-merge', 1]],
#  '1998': [['Using Queries Based', 2],
#   ['Queries Based Textual', 2],
#   ['Based Textual Similarity', 2],
#   ['SuperSQL An Extended', 1],
#   ['An Extended SQL', 1],
#   ['Extended SQL Database', 1],
#   ['SQL Database Publishing', 1],
#   ['Database Publishing Presentation', 1],
#   ['About Quark Digital', 1],
#   ['Quark Digital Media', 1]],
#  '2005': [['microsoft SQL server', 3],
#   ['XML relational database', 2],
#   ['relational database management', 2],
#   ['database management systems', 2],
#   ['management systems inside', 2],
#   ['SQL server 2005', 2],
#   ['Event processing oracle', 1],
#   ['processing oracle database', 1],
#   ['ConQuer Efficient Management', 1],
#   ['Efficient Management Inconsistent', 1]],
#  '2018': [['Knowledge Base Construction', 3],
#   ['Distributed In-Memory Trajectory', 2],
#   ['In-Memory Trajectory Analytics', 2],
#   ['Database Management Systems', 2],
#   ['In-Memory Database Systems', 2],
#   ['Motifs Data Series', 2],
#   ['Deep Reinforcement Learning', 2],
#   ['Distributed Stream Processing', 2],
#   ['Approximate Query Processing', 2],
#   ['Incremental View Maintenance', 2]],
#  '2017': [['Approximate Query Processing', 3],
#   ['FEIII 2017 Challenge', 3],
#   ['Big Data Analytics', 2],
#   ['semantic web technologies', 2],
#   ['Database Management System', 2],
#   ['Synthesizing Extraction Rules', 1],
#   ['Extraction Rules User', 1],
#   ['Rules User Examples', 1],
#   ['User Examples SEER', 1],
#   ['Query Processing Interactive', 1]],
#  '1991': [['A Retrieval Technique', 1],
#   ['Retrieval Technique Similar', 1],
#   ['Technique Similar Shapes', 1],
#   ['Version Management Composite', 1],
#   ['Management Composite Objects', 1],
#   ['Composite Objects CAD', 1],
#   ['Objects CAD Databases', 1],
#   ['Updating Relational Databases', 1],
#   ['Relational Databases Object-Based', 1],
#   ['Databases Object-Based Views', 1]],
#  '2006': [['data-driven web applications', 2],
#   ['data services platform', 2],
#   ['Efficient query processing', 2],
#   ['Data integration transform', 1],
#   ['integration transform reuse', 1],
#   ['transform reuse Morpheus', 1],
#   ['reuse Morpheus project', 1],
#   ['InMAF indexing music', 1],
#   ['indexing music databases', 1],
#   ['music databases via', 1]],
#  '2007': [['ADO.NET entity framework', 2],
#   ['Sonnet efficient distributed', 1],
#   ['efficient distributed content-based', 1],
#   ['distributed content-based dissemination', 1],
#   ['content-based dissemination broker', 1],
#   ['Why off-the-shelf RDBMSs', 1],
#   ['off-the-shelf RDBMSs better', 1],
#   ['RDBMSs better XPath', 1],
#   ['better XPath might', 1],
#   ['XPath might expect', 1]],
#  '2016': [['Wander Join Online', 2],
#   ['Join Online Aggregation', 2],
#   ['Microblogs Data Management', 2],
#   ['Optimistic Concurrency Control', 2],
#   ['interactive data exploration', 2],
#   ['A Study Sorting', 1],
#   ['Study Sorting Algorithms', 1],
#   ['Sorting Algorithms Approximate', 1],
#   ['Algorithms Approximate Memory', 1],
#   ['Viral marketing 2.0', 1]],
#  '1988': [['A Relational Database', 2],
#   ['An Object-Oriented Database', 2],
#   ['A Performance Analysis', 2],
#   ['Classification Recursive Formulas', 1],
#   ['Recursive Formulas Deductive', 1],
#   ['Formulas Deductive Databases', 1],
#   ['Optimal File Distribution', 1],
#   ['File Distribution For', 1],
#   ['Distribution For Partial', 1],
#   ['For Partial Match', 1]],
#  '2023': [['International Workshop Data', 2],
#   ['Workshop Data Management', 2],
#   ['Link Local Differential', 1],
#   ['Local Differential Privacy', 1],
#   ['Differential Privacy GNNs', 1],
#   ['Privacy GNNs via', 1],
#   ['GNNs via Bayesian', 1],
#   ['via Bayesian Estimation', 1],
#   ['Demonstrating MATE COCOA', 1],
#   ['MATE COCOA Data', 1]],
#  '1976': [['Relational Data Base', 2],
#   ['Data Base System', 2],
#   ['Application Analytical Model', 1],
#   ['Analytical Model Evaluate', 1],
#   ['Model Evaluate Storage', 1],
#   ['Evaluate Storage Structures', 1],
#   ['An Authorization Mechanism', 1],
#   ['Authorization Mechanism Relational', 1],
#   ['Mechanism Relational Data', 1],
#   ['Base System Abstract', 1]],
#  '1990': [['Graphical Interface Ode', 2],
#   ['The Postgres DBMS', 1],
#   ['Random Sampling Hash', 1],
#   ['Sampling Hash Files', 1],
#   ['A Predicate Matching', 1],
#   ['Predicate Matching Algorithm', 1],
#   ['Matching Algorithm Database', 1],
#   ['Algorithm Database Rule', 1],
#   ['Database Rule Systems', 1],
#   ['Reliable Transaction Management', 1]],
#  '2001': [['RETINA A REal-time', 1],
#   ['A REal-time TraffIc', 1],
#   ['REal-time TraffIc NAvigation', 1],
#   ['TraffIc NAvigation System', 1],
#   ['Orthogonal Optimization Subqueries', 1],
#   ['Optimization Subqueries Aggregation', 1],
#   ['Selectivity Estimation using', 1],
#   ['Estimation using Probabilistic', 1],
#   ['using Probabilistic Models', 1],
#   ['The Network Database', 1]],
#  '2022': [['Distributed Matrix Computation', 2],
#   ['Interpretable Data-Based Explanations', 2],
#   ['Data-Based Explanations Fairness', 2],
#   ['Explanations Fairness Debugging', 2],
#   ['Complex Event Processing', 2],
#   ['International Workshop Data', 2],
#   ['Machine Learning Model', 2],
#   ['using Reinforcement Learning', 2],
#   ['Database Management Systems', 2],
#   ['Interactive Visualization Interface', 2]],
#  '2009': [['Minimizing communication cost', 1],
#   ['communication cost continuous', 1],
#   ['cost continuous skyline', 1],
#   ['continuous skyline maintenance', 1],
#   ['Monitoring path nearest', 1],
#   ['path nearest neighbor', 1],
#   ['nearest neighbor road', 1],
#   ['neighbor road networks', 1],
#   ['Dictionary-based order-preserving string', 1],
#   ['order-preserving string compression', 1]],
#  '2015': [['Main-Memory Database Systems', 2],
#   ['Analysis Big Data', 2],
#   ['Large-scale Predictive Analytics', 1],
#   ['Predictive Analytics Vertica', 1],
#   ['Analytics Vertica Fast', 1],
#   ['Vertica Fast Data', 1],
#   ['Fast Data Transfer', 1],
#   ['Data Transfer Distributed', 1],
#   ['Transfer Distributed Model', 1],
#   ['Distributed Model Creation', 1]],
#  '1999': [['Approximate Query Answering', 2],
#   ['Constrained Frequent Set', 2],
#   ['Frequent Set Queries', 2],
#   ['Efficient Concurrency Control', 2],
#   ['World Wide Database', 1],
#   ['Wide Database Integrating', 1],
#   ['Database Integrating Web', 1],
#   ['Integrating Web CORBA', 1],
#   ['Web CORBA Databases', 1],
#   ['SERF ODMG-Based Generic', 1]],
#  '2004': [['Relaxed Currency Consistency', 2],
#   ['Web Query Interfaces', 2],
#   ['Relational Database System', 2],
#   ['Adaptive Ordering Pipelined', 1],
#   ['Ordering Pipelined Stream', 1],
#   ['Pipelined Stream Filters', 1],
#   ['PIPES A Public', 1],
#   ['A Public Infrastructure', 1],
#   ['Public Infrastructure Processing', 1],
#   ['Infrastructure Processing Exploring', 1]],
#  '1981': [['Deadlock Removal Using', 1],
#   ['Removal Using Partial', 1],
#   ['Using Partial Rollback', 1],
#   ['Partial Rollback Database', 1],
#   ['Rollback Database Systems', 1],
#   ['On Power Locking', 1],
#   ['The K-D-B-Tree A', 1],
#   ['K-D-B-Tree A Search', 1],
#   ['A Search Structure', 1],
#   ['Search Structure For', 1]],
#  '1996': [['A Query Language', 2],
#   ['A Content-Based Multimedia', 2],
#   ['Content-Based Multimedia Server', 2],
#   ['Multimedia Server Massively', 2],
#   ['Server Massively Parallel', 2],
#   ['Massively Parallel Architectures', 2],
#   ['Maintaining Database Consistency', 1],
#   ['Database Consistency Presence', 1],
#   ['Consistency Presence Value', 1],
#   ['Presence Value Dependencies', 1]],
#  '1997': [['DEVise Integrated Querying', 2],
#   ['The WHIPS Prototype', 1],
#   ['WHIPS Prototype Data', 1],
#   ['Prototype Data Warehouse', 1],
#   ['Data Warehouse Creation', 1],
#   ['Warehouse Creation Maintenance', 1],
#   ['A Framework Implementing', 1],
#   ['Framework Implementing Hypothetical', 1],
#   ['Implementing Hypothetical Queries', 1],
#   ['Languages Multi-database Interoperability', 1]],
#  '2019': [['Machine Learning Models', 2],
#   ['An Interactive System', 2],
#   ['Local Differential Privacy', 2],
#   ['Workshop Data Management', 2],
#   ['Big Data Analytics', 2],
#   ['User Group Analytics', 2],
#   ['Query Processing based', 2],
#   ['Speech-driven Multimodal Querying', 2],
#   ['Queries Using Small', 2],
#   ['Using Small Examples', 2]],
#  '2010': [['Boosting spatial pruning', 1],
#   ['spatial pruning optimal', 1],
#   ['pruning optimal pruning', 1],
#   ['optimal pruning MBRs', 1],
#   ['Google fusion tables', 1],
#   ['fusion tables web-centered', 1],
#   ['tables web-centered data', 1],
#   ['web-centered data management', 1],
#   ['data management collaboration', 1],
#   ['Adaptive query scheduling', 1]],
#  '2008': [['microsoft SQL server', 3],
#   ['wireless sensor networks', 2],
#   ['Graph summarization bounded', 1],
#   ['summarization bounded error', 1],
#   ['Provenance scientific workflows', 1],
#   ['scientific workflows challenges', 1],
#   ['workflows challenges opportunities', 1],
#   ['Towards identity anonymization', 1],
#   ['identity anonymization graphs', 1],
#   ['CRD fast co-clustering', 1]],
#  '2012': [['Managing mining large', 2],
#   ['mining large graphs', 2],
#   ['search relational databases', 2],
#   ['distance queries large', 2],
#   ['DP-tree indexing multi-dimensional', 1],
#   ['indexing multi-dimensional data', 1],
#   ['multi-dimensional data differential', 1],
#   ['data differential privacy', 1],
#   ['differential privacy abstract', 1],
#   ['Skew-aware automatic database', 1]],
#  '1978': [['Data Base Applications', 3],
#   ['Implementation INDY Backend', 2],
#   ['INDY Backend Kernel', 2],
#   ['View Representation Logical', 1],
#   ['Representation Logical Database', 1],
#   ['Logical Database Design', 1],
#   ['Distributed Query Processing', 1],
#   ['Query Processing Relational', 1],
#   ['Processing Relational Data', 1],
#   ['Relational Data Base', 1]],
#  '1994': [['Database Issues Telecommunications', 1],
#   ['Issues Telecommunications Network', 1],
#   ['Telecommunications Network Management', 1],
#   ['Data Replication Mobile', 1],
#   ['Replication Mobile Computers', 1],
#   ['EOS An Extensible', 1],
#   ['An Extensible Object', 1],
#   ['Extensible Object Store', 1],
#   ['Oracle Media Server', 1],
#   ['Media Server Providing', 1]],
#  '1980': [['Physical Database Design', 2],
#   ['Title Table Contents', 2],
#   ['Table Contents Preface', 2],
#   ['Abstract Data Types', 2],
#   ['Data Base Machine', 2],
#   ['An Access Path', 1],
#   ['Access Path Model', 1],
#   ['Path Model Physical', 1],
#   ['Model Physical Database', 1],
#   ['APCAM A Practical', 1]],
#  '1983': [['Database Theory Where', 1],
#   ['Theory Where Has', 1],
#   ['Where Has It', 1],
#   ['Has It Been', 1],
#   ['It Been Where', 1],
#   ['Been Where Is', 1],
#   ['Where Is It', 1],
#   ['Is It Going', 1],
#   ['It Going Abstract', 1],
#   ['DBMS AI Is', 1]],
#  '2000': [['Automatic Summary Tables', 2],
#   ['Database Middleware System', 2],
#   ['Privacy-Preserving Data Mining', 1],
#   ['DLFM A Transactional', 1],
#   ['A Transactional Resource', 1],
#   ['Transactional Resource Manager', 1],
#   ['Influence Sets Based', 1],
#   ['Sets Based Reverse', 1],
#   ['Based Reverse Nearest', 1],
#   ['Reverse Nearest Neighbor', 1]],
#  '1975': [['Data Base Management', 3],
#   ['A Data Base', 3],
#   ['Base Management System', 2],
#   ['Management System Design', 2],
#   ['Computer Aided Design', 2],
#   ['Approach Data Base', 2],
#   ['Data Base Structures', 2],
#   ['Individual Data Bases', 1],
#   ['Data Bases Circuit', 1],
#   ['Bases Circuit Design', 1]],
#  '1971': [['Data Privacy Integrity', 2],
#   ['Evolution Data Base', 1],
#   ['Data Base Management', 1],
#   ['Base Management A.O', 1],
#   ['Management A.O Smith', 1],
#   ['Expandable Open Addressing', 1],
#   ['Open Addressing Hash', 1],
#   ['Addressing Hash Table', 1],
#   ['Hash Table Storage', 1],
#   ['Table Storage Retrieval', 1]],
#  '2003': [['The Future Web', 2],
#   ['Building Notification Services', 1],
#   ['Notification Services Microsoft', 1],
#   ['Services Microsoft SQLServer', 1],
#   ['Rondo A Programming', 1],
#   ['A Programming Platform', 1],
#   ['Programming Platform Generic', 1],
#   ['Platform Generic Model', 1],
#   ['Generic Model Management', 1],
#   ['Gigascope A Stream', 1]],
#  '2011': [['Concept disambiguation exploiting', 1],
#   ['disambiguation exploiting semantic', 1],
#   ['exploiting semantic databases', 1],
#   ['What real SPARQL', 1],
#   ['real SPARQL queries', 1],
#   ['SPARQL queries like', 1],
#   ['Ranking uncertain scoring', 1],
#   ['uncertain scoring functions', 1],
#   ['scoring functions semantics', 1],
#   ['functions semantics sensitivity', 1]],
#  '1986': [['Database Management Systems', 2],
#   ['On Evaluation Strategy', 1],
#   ['Evaluation Strategy EDUCE', 1],
#   ['Prefetching Realtime Database', 1],
#   ['Realtime Database Applications', 1],
#   ['User Interfaces Database', 1],
#   ['Interfaces Database Management', 1],
#   ['Engineering Information Systems', 1],
#   ['Information Systems Builders', 1],
#   ['Systems Builders Designers', 1]],
#  '1992': [['Extending Ingres Methods', 1],
#   ['Ingres Methods Triggers', 1],
#   ['A Qualitative Comparison', 1],
#   ['Qualitative Comparison Study', 1],
#   ['Comparison Study Data', 1],
#   ['Study Data Structures', 1],
#   ['Data Structures Large', 1],
#   ['Structures Large Line', 1],
#   ['Large Line Segment', 1],
#   ['Line Segment Databases', 1]],
#  '1995': [['Object Query Languages', 2],
#   ['VisDB A System', 1],
#   ['A System Visualizing', 1],
#   ['System Visualizing Large', 1],
#   ['Visualizing Large Databases', 1],
#   ['Leveraging The Information', 1],
#   ['The Information Asset', 1],
#   ['The Algres Testbed', 1],
#   ['Algres Testbed CHIMERA', 1],
#   ['Testbed CHIMERA An', 1]],
#  '1972': [['Stored Data Definition', 2],
#   ['Data Definition Translation', 2],
#   ['Data Independent Accessing', 2],
#   ['Independent Accessing Model', 2],
#   ['A Development Model', 1],
#   ['Development Model Data', 1],
#   ['Model Data Translation', 1],
#   ['Binary Search Trees', 1],
#   ['Search Trees File', 1],
#   ['Trees File Organization', 1]],
#  '1982': [['Database Management System', 3],
#   ['Fast Methods Testing', 1],
#   ['Methods Testing Quantified', 1],
#   ['Testing Quantified Relational', 1],
#   ['Quantified Relational Calculus', 1],
#   ['Relational Calculus Assertions', 1],
#   ['Query Processing Strategies', 1],
#   ['Processing Strategies PASCAL/R', 1],
#   ['Strategies PASCAL/R Relational', 1],
#   ['PASCAL/R Relational Database', 1]],
#  '1993': [['CORAL Deductive Database', 2],
#   ['Deductive Database System', 2],
#   ['Evaluation Signature Files', 1],
#   ['Signature Files Set', 1],
#   ['Files Set Access', 1],
#   ['Set Access Facilities', 1],
#   ['Access Facilities OODBs', 1],
#   ['Interoperability Using APPC', 1],
#   ['Doubly Distorted Mirrors', 1],
#   ['An Instant Accurate', 1]],
#  '1989': [['Evaluating Size Queries', 1],
#   ['Size Queries Relational', 1],
#   ['Queries Relational Databases', 1],
#   ['Relational Databases non', 1],
#   ['Databases non Uniform', 1],
#   ['non Uniform Distribution', 1],
#   ['Uniform Distribution Stochastic', 1],
#   ['Distribution Stochastic Dependence', 1],
#   ['Conflict Resolution Rules', 1],
#   ['Resolution Rules Assigning', 1]],
#  '1977': [['A Practical Deadlock', 1],
#   ['Practical Deadlock Avoidance', 1],
#   ['Deadlock Avoidance Algorithm', 1],
#   ['Avoidance Algorithm Data', 1],
#   ['Algorithm Data Base', 1],
#   ['Data Base Systems', 1],
#   ['Concurrency Database Systems', 1],
#   ['Database Systems A', 1],
#   ['Systems A Simulation', 1],
#   ['A Simulation Study', 1]],
#  '1987': [['Data Management Systems', 2],
#   ['Rule Trading Memory', 2],
#   ['A Data Management', 1],
#   ['Data Management Extension', 1],
#   ['Management Extension Architecture', 1],
#   ['Operating System Support', 1],
#   ['System Support Data', 1],
#   ['Support Data Management', 1],
#   ['The Design ¬1NF', 1],
#   ['Design ¬1NF Relational', 1]],
#  '1985': [['Distributed Database Systems', 2],
#   ['Adaptive Information System', 1],
#   ['Information System Design', 1],
#   ['System Design One', 1],
#   ['Design One Query', 1],
#   ['One Query Time', 1],
#   ['A Decomposition Storage', 1],
#   ['Decomposition Storage Model', 1],
#   ['Recovery Architectures Multiprocessor', 1],
#   ['Architectures Multiprocessor Database', 1]],
#  '1979': [['Data Base Management', 2],
#   ['The Data Management', 1],
#   ['Data Management Facilities', 1],
#   ['Management Facilities PLAIN', 1],
#   ['Evaluation Transmission Requirements', 1],
#   ['Transmission Requirements Distributed', 1],
#   ['Requirements Distributed Database', 1],
#   ['Distributed Database Access', 1],
#   ['An Optimality Theory', 1],
#   ['Optimality Theory Concurrency', 1]],
#  '1984': [['A Methodology Database', 1],
#   ['Methodology Database System', 1],
#   ['Database System Performance', 1],
#   ['System Performance Evaluation', 1],
#   ['Optimal Computation Total', 1],
#   ['Computation Total Projections', 1],
#   ['Total Projections Unions', 1],
#   ['Projections Unions Simple', 1],
#   ['Unions Simple Chase', 1],
#   ['Simple Chase Join', 1]],
#  '1970': [['Storage Structure Definition', 6],
#   ['Structure Definition Language', 5],
#   ['Definition Language SSDL', 2],
#   ['Preliminary Discussion General', 1],
#   ['Discussion General Data', 1],
#   ['General Data Storage', 1],
#   ['Data Storage Structure', 1],
#   ['Storage Structure Mapping', 1],
#   ['Structure Mapping Language', 1],
#   ['A Multilevel Data', 1]]}

# %% [markdown]
# ### Nouns only

# %%
sw = set(stopwords.words("english") + list(string.punctuation))
counts_nouns = defaultdict(lambda:defaultdict(int))
for k, v in titles_by_date.items():
    for t in v:
        if t:
            tokens = word_tokenize(t)
            tokens = nltk.pos_tag(tokens)
            tokens = [word[0] for word in tokens if ((not word[0] in sw) and (word[1]=='NN'))]
            for tok in tokens:
                counts_nouns[k][tok] += 1

# %%
toptennouns = dict()
for k, v in counts_nouns.items():
    _ = [[k,v] for k,v in v.items()]
    _ = sorted(_,key=lambda x: x[1],reverse=True)
    top = _[:10]
    toptennouns[k] = top

# %%
toptennouns
# Out:
# {'2021': [['System', 5],
#   ['Storage', 3],
#   ['learning', 3],
#   ['Approach', 3],
#   ['serverless', 2],
#   ['Scaling', 2],
#   ['training', 2],
#   ['edge', 2],
#   ['influence', 2],
#   ['maximization', 2]],
#  '1974': [['Processing', 1],
#   ['Information', 1],
#   ['View', 1],
#   ['Declaration', 1],
#   ['Methodology', 1],
#   ['Approach', 1],
#   ['SEQUEL', 1],
#   ['replacement', 1],
#   ['Architecture', 1],
#   ['Equivalence', 1]],
#  '2020': [['learning', 6],
#   ['System', 5],
#   ['query', 5],
#   ['Analysis', 4],
#   ['processing', 3],
#   ['machine', 3],
#   ['knowledge', 2],
#   ['graph', 2],
#   ['Cost', 2],
#   ['Processing', 2]],
#  '2013': [['query', 14],
#   ['system', 14],
#   ['graph', 13],
#   ['processing', 12],
#   ['database', 12],
#   ['analysis', 10],
#   ['management', 9],
#   ['mining', 9],
#   ['search', 8],
#   ['cloud', 7]],
#  '2014': [['query', 19],
#   ['processing', 14],
#   ['graphs', 12],
#   ['search', 10],
#   ['graph', 9],
#   ['database', 8],
#   ['framework', 6],
#   ['data', 5],
#   ['optimization', 5],
#   ['approach', 5]],
#  '2002': [['database', 11],
#   ['query', 5],
#   ['search', 4],
#   ['network', 4],
#   ['processing', 3],
#   ['caching', 3],
#   ['system', 3],
#   ['pattern', 3],
#   ['information', 3],
#   ['web', 3]],
#  '1998': [['Storage', 2],
#   ['Query', 2],
#   ['SuperSQL', 1],
#   ['Exploratory', 1],
#   ['Interaction', 1],
#   ['Conversion', 1],
#   ['Cost', 1],
#   ['Traffic', 1],
#   ['MultiMediaMiner', 1],
#   ['CURE', 1]],
#  '2005': [['system', 7],
#   ['management', 5],
#   ['processing', 4],
#   ['database', 4],
#   ['information', 4],
#   ['integration', 4],
#   ['XML', 4],
#   ['server', 4],
#   ['oracle', 2],
#   ['enterprise', 2]],
#  '2018': [['Demonstration', 4],
#   ['Approach', 3],
#   ['System', 3],
#   ['DITA', 2],
#   ['Analysis', 2],
#   ['Pinot', 1],
#   ['BIPie', 1],
#   ['TopPPR', 1],
#   ['Columnstore', 1],
#   ['TurboGraph++', 1]],
#  '2017': [['Demonstration', 5],
#   ['Approach', 4],
#   ['approach', 3],
#   ['web', 3],
#   ['Foofah', 2],
#   ['management', 2],
#   ['Exploration', 2],
#   ['Performance', 2],
#   ['Store', 2],
#   ['Encryption', 2]],
#  '1991': [['Approach', 2],
#   ['Language', 2],
#   ['Evaluation', 2],
#   ['Store', 1],
#   ['Segment', 1],
#   ['Trait', 1],
#   ['Concurrency', 1],
#   ['Glue-Nail', 1],
#   ['Analysis', 1],
#   ['HYDRO', 1]],
#  '2006': [['query', 11],
#   ['search', 9],
#   ['database', 8],
#   ['processing', 7],
#   ['web', 6],
#   ['management', 5],
#   ['analysis', 4],
#   ['system', 4],
#   ['performance', 4],
#   ['monitoring', 4]],
#  '2007': [['database', 11],
#   ['query', 9],
#   ['processing', 9],
#   ['management', 6],
#   ['engine', 6],
#   ['information', 6],
#   ['estimation', 5],
#   ['system', 4],
#   ['framework', 4],
#   ['search', 4]],
#  '2016': [['exploration', 11],
#   ['analysis', 4],
#   ['system', 3],
#   ['learning', 3],
#   ['Evaluation', 3],
#   ['management', 3],
#   ['query', 3],
#   ['machine', 3],
#   ['algorithms', 3],
#   ['classification', 2]],
#  '1988': [['Analysis', 3],
#   ['Performance', 3],
#   ['Classification', 1],
#   ['Characterization', 1],
#   ['Environment', 1],
#   ['Partition', 1],
#   ['Framework', 1],
#   ['Storage', 1],
#   ['LCE', 1],
#   ['Point', 1]],
#  '2023': [['Demonstration', 5],
#   ['From', 2],
#   ['System', 2],
#   ['Dike', 1],
#   ["GRADES-NDA'23", 1],
#   ['SHACTOR', 1],
#   ['Quality', 1],
#   ['SynopsisDB', 1],
#   ['SparkSQL+', 1],
#   ['aiDM', 1]],
#  '1976': [['Application', 2],
#   ['Model', 1],
#   ['Authorization', 1],
#   ['Approach', 1],
#   ['NUL', 1],
#   ['Performance', 1],
#   ['Information', 1],
#   ['Index', 1],
#   ['Retrieval', 1],
#   ['LSL', 1]],
#  '1990': [['OdeView', 2],
#   ['Framework', 1],
#   ['Production', 1],
#   ['-Tree', 1],
#   ['Kaleidoscope', 1],
#   ['Pasta-3', 1],
#   ['Bayan', 1],
#   ['Language', 1],
#   ['FastSort', 1],
#   ['Evaluation', 1]],
#  '2001': [['System', 2],
#   ['Prototype', 2],
#   ['Solution', 2],
#   ['Efficient', 2],
#   ['Optimization', 2],
#   ['XML', 2],
#   ['Approach', 2],
#   ['RETINA', 1],
#   ['Database', 1],
#   ['PREFER', 1]],
#  '2022': [['Approach', 4],
#   ['Demonstration', 3],
#   ['Evaluation', 2],
#   ['framework', 2],
#   ['Proteus', 2],
#   ['index', 2],
#   ['Storage', 2],
#   ['DB-BERT', 2],
#   ['OTIF', 1],
#   ['VoiceQuerySystem', 1]],
#  '2009': [['search', 12],
#   ['database', 11],
#   ['query', 8],
#   ['analysis', 7],
#   ['optimization', 6],
#   ['keyword', 6],
#   ['web', 6],
#   ['memory', 5],
#   ['extraction', 5],
#   ['processing', 5]],
#  '2015': [['Storage', 4],
#   ['Query', 3],
#   ['Approach', 2],
#   ['Search', 2],
#   ['DunceCap', 2],
#   ['System', 2],
#   ['Aggregation', 1],
#   ['Hashing', 1],
#   ['X-Ray', 1],
#   ['Tool', 1]],
#  '1999': [['Query', 3],
#   ['Optimization', 3],
#   ['SERF', 1],
#   ['Integration', 1],
#   ['Exploratory', 1],
#   ['Interface', 1],
#   ['TAM', 1],
#   ['Phoenix', 1],
#   ['DBIS-Toolkit', 1],
#   ['Building', 1]],
#  '2004': [['Query', 3],
#   ['Infrastructure', 2],
#   ['Approach', 2],
#   ['Evaluation', 2],
#   ['XML', 2],
#   ['Information', 2],
#   ['Structure', 2],
#   ['XSeq', 1],
#   ['Secure', 1],
#   ['Support', 1]],
#  '1981': [['Structure', 1],
#   ['Evaluation', 1],
#   ['Precision', 1],
#   ['Introduction', 1],
#   ['Form', 1],
#   ['Operation', 1],
#   ['Information', 1],
#   ['Database', 1],
#   ['Derivability', 1]],
#  '1996': [['Storage', 2],
#   ['CapBasED-AMS', 1],
#   ['Rule', 1],
#   ['Scheme', 1],
#   ['Support', 1],
#   ['Query', 1],
#   ['Optimization', 1],
#   ['Reordering', 1],
#   ['IDEA', 1],
#   ['Execution', 1]],
#  '1997': [['DEVise', 2],
#   ['STRUDEL', 1],
#   ['SENTINEL', 1],
#   ['Performance', 1],
#   ['MDM', 1],
#   ['Tool', 1],
#   ['GeoMiner', 1],
#   ['Beyond', 1],
#   ['SEMCOG', 1],
#   ['Cubetree', 1]],
#  '2019': [['System', 4],
#   ['Demonstration', 4],
#   ['learning', 3],
#   ['From', 2],
#   ['web', 2],
#   ['Pricing', 2],
#   ['Provenance', 2],
#   ['Summarization', 1],
#   ['abort', 1],
#   ['prediction', 1]],
#  '2010': [['search', 13],
#   ['query', 12],
#   ['processing', 11],
#   ['database', 10],
#   ['system', 10],
#   ['information', 7],
#   ['approach', 7],
#   ['graph', 5],
#   ['management', 4],
#   ['integration', 4]],
#  '2008': [['database', 14],
#   ['system', 11],
#   ['query', 11],
#   ['search', 8],
#   ['processing', 6],
#   ['graphs', 4],
#   ['optimization', 4],
#   ['testing', 4],
#   ['case', 4],
#   ['data', 4]],
#  '2012': [['search', 13],
#   ['database', 11],
#   ['graphs', 9],
#   ['management', 8],
#   ['query', 8],
#   ['processing', 8],
#   ['system', 7],
#   ['optimization', 6],
#   ['privacy', 5],
#   ['keyword', 5]],
#  '1978': [['Evaluation', 2],
#   ['Design', 1],
#   ['Storage', 1],
#   ['Implementation', 1],
#   ['Review', 1],
#   ['Architecture', 1],
#   ['Consistency', 1],
#   ['Structure', 1],
#   ['Editing', 1],
#   ['Procedure', 1]],
#  '1994': [['System', 3],
#   ['XSB', 2],
#   ['Page', 2],
#   ['EOS', 1],
#   ['Object', 1],
#   ['Scalability', 1],
#   ['Year', 1],
#   ['AlphaSort', 1],
#   ['Query', 1],
#   ['ARIES/CSA', 1]],
#  '1980': [['discussion', 8],
#   ['Approach', 2],
#   ['Abstraction', 2],
#   ['Language', 2],
#   ['Relativism', 1],
#   ['Image', 1],
#   ['Perspective', 1],
#   ['View', 1],
#   ['DIAL', 1],
#   ['Extension', 1]],
#  '1983': [['Experience', 2],
#   ['Environment', 2],
#   ['Theory', 1],
#   ['Database', 1],
#   ['Office', 1],
#   ['SOS', 1],
#   ['Resolution', 1],
#   ['Use', 1],
#   ['Application', 1],
#   ['Performance', 1]],
#  '2000': [['System', 2],
#   ['MOCHA', 2],
#   ['DLFM', 1],
#   ['Join', 1],
#   ['WSQ/DSQ', 1],
#   ['Maintenance', 1],
#   ['XMILL', 1],
#   ['Indexing', 1],
#   ['TerraServer', 1],
#   ['XTRACT', 1]],
#  '1975': [['Implementation', 3],
#   ['Approach', 3],
#   ['System', 3],
#   ['File', 1],
#   ['Environment', 1],
#   ['Application', 1],
#   ['Performance', 1],
#   ['Database', 1],
#   ['Information', 1],
#   ['CONVERT', 1]],
#  '1971': [['Storage', 2],
#   ['Structure', 2],
#   ['Evolution', 1],
#   ['Optimization', 1],
#   ['Information', 1],
#   ['Evaluation', 1],
#   ['Architecture', 1],
#   ['Analysis', 1]],
#  '2003': [['Future', 2],
#   ['XQuery', 2],
#   ['Query', 2],
#   ['Rondo', 1],
#   ['Platform', 1],
#   ['Gigascope', 1],
#   ['SOCQET', 1],
#   ['TIMBER', 1],
#   ['Qcluster', 1],
#   ['Language', 1]],
#  '2011': [['search', 15],
#   ['query', 13],
#   ['system', 9],
#   ['analysis', 8],
#   ['database', 8],
#   ['processing', 6],
#   ['management', 6],
#   ['information', 5],
#   ['approach', 5],
#   ['algorithms', 5]],
#  '1986': [['Approach', 2],
#   ['Query', 2],
#   ['Processing', 2],
#   ['Information', 1],
#   ['Message', 1],
#   ['Version', 1],
#   ['Inheritance', 1],
#   ['Neptune', 1],
#   ['Evaluation', 1],
#   ['Abstraction', 1]],
#  '1992': [['Optimization', 2],
#   ['Analysis', 1],
#   ['Administration', 1],
#   ['DOODLE', 1],
#   ['Language', 1],
#   ['ARIES/IM', 1],
#   ['Extensible/Rule', 1],
#   ['Approach', 1],
#   ['Experience', 1],
#   ['Implementation', 1]],
#  '1995': [['System', 2],
#   ['Query', 2],
#   ['Execution', 2],
#   ['Storage', 2],
#   ['VisDB', 1],
#   ['OFL', 1],
#   ['PTool', 1],
#   ['FastMap', 1],
#   ['Replication', 1],
#   ['Language', 1]],
#  '1972': [['Approach', 3], ['Storage', 1], ['Structure', 1]],
#  '1982': [['Query', 2],
#   ['Language', 2],
#   ['ERQ', 1],
#   ['Implementation', 1],
#   ['Optimization', 1],
#   ['Approach', 1],
#   ['Technique', 1],
#   ['Architecture', 1],
#   ['Analysis', 1],
#   ['Transaction', 1]],
#  '1993': [['Implementation', 2],
#   ['Information', 2],
#   ['Evaluation', 1],
#   ['Environment', 1],
#   ['Persistence', 1],
#   ['Software', 1],
#   ['oo7', 1],
#   ['Constraint', 1],
#   ['Index', 1],
#   ['Migration', 1]],
#  '1989': [['Evaluation', 2],
#   ['Approach', 1],
#   ['language', 1],
#   ['Performance', 1],
#   ['Tool', 1],
#   ['versionControl', 1],
#   ['CLASSIC', 1],
#   ['Model', 1],
#   ['Database', 1],
#   ['Redundancy', 1]],
#  '1977': [['Approach', 2],
#   ['Concurrency', 1],
#   ['Simulation', 1],
#   ['Application', 1],
#   ['Implementation', 1],
#   ['Update-by-Dialogue', 1],
#   ['Axiomatization', 1],
#   ['Study', 1],
#   ['Classification', 1],
#   ['IAM', 1]],
#  '1987': [['Analysis', 2],
#   ['Optimization', 2],
#   ['Operating', 1],
#   ['Condition', 1],
#   ['Security', 1],
#   ['Population', 1],
#   ['Experience', 1],
#   ['Transaction', 1],
#   ['Storage', 1],
#   ['Reclamation', 1]],
#  '1985': [['Language', 2],
#   ['Query', 1],
#   ['Recovery', 1],
#   ['Optimization', 1],
#   ['Approach', 1],
#   ['ISIS', 1],
#   ['Interface', 1],
#   ['Information', 1],
#   ['Analysis', 1],
#   ['Genesis', 1]],
#  '1979': [['Evaluation', 1],
#   ['Transmission', 1],
#   ['Cost', 1],
#   ['Design', 1],
#   ['Execution', 1],
#   ['Approach', 1]],
#  '1984': [['Implementation', 2],
#   ['Maintenance', 1],
#   ['Design', 1],
#   ['Integrity', 1],
#   ['PRISM', 1],
#   ['Overview', 1],
#   ['Condition', 1],
#   ['Operating', 1],
#   ['Back-End', 1]],
#  '1970': [['summary', 9],
#   ['pre-discussion', 6],
#   ['Storage', 6],
#   ['CODASYL', 2],
#   ['Information', 1],
#   ['Translation', 1],
#   ['Understanding', 1],
#   ['Introduction', 1],
#   ['transcript', 1],
#   ['Organization', 1]]}

# %% [markdown]
# ### top 10 bigram nouns

# %%
sw = set(stopwords.words("english") + list(string.punctuation))
counts_bigrams_nouns = defaultdict(lambda:defaultdict(int))
for k, v in titles_by_date.items():
    for t in v:
        if t:
            tokens = word_tokenize(t)
            tokens = nltk.pos_tag(tokens)
            tokens = [word[0] for word in tokens if ((not word[0] in sw) and (word[1]=='NN'))]
            ngs = ngrams(tokens,2)
            for gram in ngs:
                counts_bigrams_nouns[k][TreebankWordDetokenizer().detokenize(gram)] += 1

# %%
toptenbigramnouns = dict()
for k, v in counts_bigrams_nouns.items():
    _ = [[k,v] for k,v in v.items()]
    _ = sorted(_,key=lambda x: x[1],reverse=True)
    top = _[:10]
    toptenbigramnouns[k] = top

# %%
toptenbigramnouns
# Out:
# {'2021': [['influence maximization', 2],
#   ['Bao Making', 1],
#   ['serverless farm', 1],
#   ['farm management', 1],
#   ['iTurboGraph Scaling', 1],
#   ['EIRES Integration', 1],
#   ['training algorithms', 1],
#   ['blockchain offloading', 1],
#   ['offloading edge', 1],
#   ['PyExplore Query', 1]],
#  '2020': [['machine learning', 3],
#   ['knowledge graph', 2],
#   ['schema knowledge', 1],
#   ['graph leveraging', 1],
#   ['leveraging knowledge', 1],
#   ['graph taxonomy', 1],
#   ['taxonomy learning', 1],
#   ['language processing', 1],
#   ['processing enterprise', 1],
#   ['Cost Processing', 1]],
#  '2013': [['query processing', 3],
#   ['bisimulation graphs', 2],
#   ['query optimization', 2],
#   ['labeling scheme', 2],
#   ['independence precomputation', 1],
#   ['similarity-search distance', 1],
#   ['GraphBuilder graph', 1],
#   ['graph framework', 1],
#   ['QUBLE blending', 1],
#   ['blending subgraph', 1]],
#  '2014': [['query processing', 7],
#   ['similarity search', 3],
#   ['community detection', 2],
#   ['behavior modeling', 2],
#   ['fast query', 2],
#   ['construction exploration', 2],
#   ['query optimization', 2],
#   ['optimization sofa', 1],
#   ['under-utilization love', 1],
#   ['Influence maximization', 1]],
#  '2002': [['query processing', 2],
#   ['tuning part', 2],
#   ['query optimization', 2],
#   ['HD-Eye clustering', 1],
#   ['GEA toolkit', 1],
#   ['toolkit gene', 1],
#   ['gene expression', 1],
#   ['expression analysis', 1],
#   ['StatiX making', 1],
#   ['making count', 1]],
#  '1998': [['Query Generalization', 1],
#   ['Xmas Storage', 1],
#   ['ARIADNE System', 1],
#   ['Replication Practicality', 1]],
#  '2005': [['processing oracle', 2],
#   ['XML database', 2],
#   ['database management', 2],
#   ['stream processing', 2],
#   ['oracle database', 1],
#   ['Enterprise information', 1],
#   ['information integration', 1],
#   ['Impact enterprise', 1],
#   ['enterprise information', 1],
#   ['database tuning', 1]],
#  '2018': [['Type Coordination', 1],
#   ['PREFER PREdiction', 1],
#   ['Snowtrail Testing', 1],
#   ['X Discovery', 1],
#   ['PISTIS Conflict', 1],
#   ['G-CORE Core', 1],
#   ['PlinyCompute Platform', 1],
#   ['FlameStream Model', 1],
#   ['TcpRT Instrument', 1],
#   ['competitor company', 1]],
#  '2017': [['framework pipeline', 1],
#   ['interest vehicle', 1],
#   ['approach crawling', 1],
#   ['BEAS Evaluation', 1],
#   ['sharing wildlife', 1],
#   ['Foofah System', 1],
#   ['check web', 1],
#   ['web application', 1],
#   ['application emergency', 1],
#   ['emergency management', 1]],
#  '1991': [['LLO Language', 1], ['Optimization Evaluation', 1]],
#  '2006': [['query processing', 5],
#   ['web search', 2],
#   ['monitoring sensor', 2],
#   ['integration transform', 1],
#   ['transform reuse', 1],
#   ['reuse project', 1],
#   ['InMAF indexing', 1],
#   ['indexing music', 1],
#   ['VizQL language', 1],
#   ['language query', 1]],
#  '2007': [['query processing', 3],
#   ['database management', 2],
#   ['metasearch engine', 2],
#   ['processing engine', 2],
#   ['entity framework', 2],
#   ['Sonnet dissemination', 1],
#   ['dissemination broker', 1],
#   ['Storage workload', 1],
#   ['workload estimation', 1],
#   ['estimation database', 1]],
#  '2016': [['query language', 2],
#   ['machine learning', 2],
#   ['QUEPA QUerying', 1],
#   ['QUerying Polystore', 1],
#   ['classification process', 1],
#   ['process reasoning', 1],
#   ['CourseNavigator path', 1],
#   ['path exploration', 1],
#   ['FERARI Prototype', 1],
#   ['Shasta Reporting', 1]],
#  '1988': [['Performance Analysis', 2], ['Trading Database', 1]],
#  '2023': [['SHACTOR Quality', 1],
#   ['Vision Reality', 1],
#   ['TeeBench Seamless', 1],
#   ['SCAD Scalability', 1],
#   ['CoWrangler Recommender', 1],
#   ['SMILE System', 1],
#   ['Demonstration Provenance', 1],
#   ['Provenance Extraction', 1],
#   ['Demonstration Answering', 1],
#   ['Demonstration System', 1]],
#  '1976': [['Application Model', 1]],
#  '2001': [['PREFER System', 1],
#   ['Snowball Prototype', 1],
#   ['Prototype System', 1],
#   ['computation PC', 1],
#   ['framework XML', 1],
#   ['VQBD Exploring', 1],
#   ['Clio Tool', 1]],
#  '2022': [["GRADES-NDA'22 management", 1],
#   ['Era Management', 1],
#   ['HumanAL calibrating', 1],
#   ['calibrating task', 1],
#   ['Skeena Efficient', 1],
#   ['TimeUnion Architecture', 1],
#   ['Analysis Evaluation', 1],
#   ['quest framework', 1],
#   ['framework classification', 1],
#   ['research health', 1]],
#  '2009': [['keyword search', 3],
#   ['memory technology', 2],
#   ['join processing', 2],
#   ['management system', 2],
#   ['information extraction', 2],
#   ['communication cost', 1],
#   ['cost maintenance', 1],
#   ['Query output', 1],
#   ['path neighbor', 1],
#   ['neighbor road', 1]],
#  '2015': [['Aggregation Hashing', 1],
#   ['X-Ray Tool', 1],
#   ['COMMIT Approach', 1],
#   ['SharkDB Storage', 1],
#   ['Purity Building', 1],
#   ['Building Storage', 1],
#   ['Query Query', 1],
#   ['FTT System', 1],
#   ['Deduplication Approach', 1],
#   ['DunceCap Query', 1]],
#  '2004': [['XSeq Infrastructure', 1],
#   ['XML XQuery', 1],
#   ['TOSS Extension', 1],
#   ['Extension TAX', 1],
#   ['MAIDS Mining', 1],
#   ['iMAP Discovering', 1],
#   ['SoundCompass Query-by-Humming', 1],
#   ['Security State', 1],
#   ['Transaction support', 1],
#   ['BLAS XPath', 1]],
#  '1981': [['Form Operation', 1],
#   ['Information Database', 1],
#   ['Database Derivability', 1]],
#  '1996': [['Storage Support', 1],
#   ['Optimization Reordering', 1],
#   ['SONAR System', 1],
#   ['Language Design', 1],
#   ['DBMiner Mining', 1],
#   ['Thinksheet Tool', 1],
#   ['Trading Space', 1]],
#  '1997': [['MDM Tool', 1],
#   ['Cubetree Organization', 1],
#   ['Index Structure', 1],
#   ['DBMS Technology', 1]],
#  '2019': [['abort prediction', 1],
#   ['CLASH Abstraction', 1],
#   ['Visus System', 1],
#   ['ExplainIt Root-cause', 1],
#   ['Osprey Supervision', 1],
#   ['Approach andResult', 1],
#   ['schema extraction', 1],
#   ['extraction knowledge', 1],
#   ['possibility trade', 1],
#   ['trade network', 1]],
#  '2010': [['information extraction', 4],
#   ['graph processing', 2],
#   ['processing cloud', 2],
#   ['search document', 2],
#   ['similarity search', 2],
#   ['pruning pruning', 1],
#   ['fusion management', 1],
#   ['management collaboration', 1],
#   ['query scheduling', 1],
#   ['scheduling database', 1]],
#  '2008': [['case study', 3],
#   ['query optimization', 2],
#   ['query processing', 2],
#   ['database system', 2],
#   ['similarity search', 2],
#   ['wireless sensor', 2],
#   ['stream processing', 2],
#   ['summarization error', 1],
#   ['identity anonymization', 1],
#   ['anonymization graphs', 1]],
#  '2012': [['keyword search', 5],
#   ['event processing', 2],
#   ['distance graphs', 2],
#   ['generation database', 2],
#   ['data management', 2],
#   ['information extraction', 2],
#   ['database shared-nothing', 1],
#   ['Probase taxonomy', 1],
#   ['taxonomy text', 1],
#   ['text understanding', 1]],
#  '1978': [['Storage Implementation', 1]],
#  '1994': [['EOS Object', 1],
#   ['GENESYS System', 1],
#   ['Enterprise Information', 1],
#   ['ASSET System', 1],
#   ['QuickStore Performance', 1],
#   ['Quest Project', 1]],
#  '1980': [['DIAL Language', 1],
#   ['Consistency discussion', 1],
#   ['Application discussion', 1]],
#  '1983': [['Resolution Environment', 1], ['Range Nesting', 1]],
#  '2000': [['XTRACT System', 1],
#   ['Index Research', 1],
#   ['Image Mining', 1],
#   ['Application Architecture', 1],
#   ['AQR-Toolkit Query', 1],
#   ['Auto-Configuration Tool', 1],
#   ['TIP Extension', 1],
#   ['javax.XXL prototype', 1],
#   ['prototype processing', 1]],
#  '1975': [['Environment Application', 1], ['Approach System', 1]],
#  '1971': [['Storage Optimization', 1], ['Storage Structure', 1]],
#  '2003': [['Rondo Platform', 1],
#   ['XQuery Language', 1],
#   ['XPRESS Compression', 1],
#   ['distribution replication', 1],
#   ['QXtract Building', 1],
#   ['Chain Operator', 1],
#   ['PeerDB Peering', 1],
#   ['LockX System', 1],
#   ['similarity search', 1],
#   ['search classification', 1]],
#  '2011': [['information extraction', 3],
#   ['similarity search', 3],
#   ['query processing', 2],
#   ['performance analysis', 2],
#   ['query processor', 2],
#   ['Search computing', 1],
#   ['computing search', 1],
#   ['search data', 1],
#   ['WINACS construction', 1],
#   ['construction analysis', 1]],
#  '1986': [['Query Processing', 2]],
#  '1992': [['DOODLE Language', 1],
#   ['Query Processing', 1],
#   ['Termination Determinism', 1]],
#  '1995': [['VisDB System', 1],
#   ['OFL Execution', 1],
#   ['Architecture Storage', 1],
#   ['QBI Query', 1],
#   ['Storage Technology', 1],
#   ['InfoHarness System', 1],
#   ['panel exchange', 1]],
#  '1993': [['Persistence Software', 1],
#   ['Design Implementation', 1],
#   ['SIMS Retrieving', 1],
#   ['Retrieving Information', 1],
#   ['Signature Tool', 1]],
#  '1977': [['Concurrency Simulation', 1],
#   ['Update-by-Dialogue Approach', 1],
#   ['Analysis Approach', 1],
#   ['Ulisse project', 1],
#   ['project terminal', 1],
#   ['terminal system', 1],
#   ['Recovery Filing', 1],
#   ['Filing System', 1]],
#  '1987': [['Population Analysis', 1],
#   ['Storage Reclamation', 1],
#   ['Design Evaluation', 1]],
#  '1985': [['ISIS Interface', 1],
#   ['Interface Information', 1],
#   ['Language Organization', 1]],
#  '1979': [['Evaluation Transmission', 1]],
#  '1984': [['Design Integrity', 1], ['Implementation Back-End', 1]],
#  '1970': [['pre-discussion summary', 6],
#   ['CODASYL Storage', 2],
#   ['Translation summary', 1],
#   ['Storage pre-discussion', 1],
#   ['Storage Storage', 1],
#   ['Storage summary', 1]]}

# %% [markdown]
# ### top 10 trigram nouns

# %%
sw = set(stopwords.words("english") + list(string.punctuation))
counts_trigrams_nouns = defaultdict(lambda:defaultdict(int))
for k, v in titles_by_date.items():
    for t in v:
        if t:
            tokens = word_tokenize(t)
            tokens = nltk.pos_tag(tokens)
            tokens = [word[0] for word in tokens if ((not word[0] in sw) and (word[1]=='NN'))]
            ngs = ngrams(tokens,3)
            for gram in ngs:
                counts_trigrams_nouns[k][TreebankWordDetokenizer().detokenize(gram)] += 1

# %%
toptentrigramnouns = dict()
for k, v in counts_trigrams_nouns.items():
    _ = [[k,v] for k,v in v.items()]
    _ = sorted(_,key=lambda x: x[1],reverse=True)
    top = _[:10]
    toptentrigramnouns[k] = top

# %%
toptentrigramnouns
# Out:
# {'2021': [['serverless farm management', 1],
#   ['blockchain offloading edge', 1],
#   ['influence maximization influence', 1],
#   ['maximization influence maximization', 1],
#   ['influence maximization benchmarker', 1],
#   ['maximization benchmarker suite', 1],
#   ['network training tuning', 1],
#   ['VSS Storage System', 1],
#   ['Machine learning translation', 1],
#   ['LSQB subgraph query', 1]],
#  '2020': [['schema knowledge graph', 1],
#   ['knowledge graph leveraging', 1],
#   ['graph leveraging knowledge', 1],
#   ['leveraging knowledge graph', 1],
#   ['knowledge graph taxonomy', 1],
#   ['graph taxonomy learning', 1],
#   ['language processing enterprise', 1],
#   ['Geopriv4j source repository', 1],
#   ['source repository location', 1],
#   ['repository location privacy', 1]],
#  '2013': [['GraphBuilder graph framework', 1],
#   ['QUBLE blending subgraph', 1],
#   ['blending subgraph query', 1],
#   ['subgraph query formulation', 1],
#   ['query formulation query', 1],
#   ['formulation query processing', 1],
#   ['Resa realtime cloud', 1],
#   ['GPText analysis framework', 1],
#   ['management business process', 1],
#   ['business process management', 1]],
#  '2014': [['fast query processing', 2],
#   ['Influence maximization time', 1],
#   ['maximization time complexity', 1],
#   ['time complexity efficiency', 1],
#   ['comparison scale machine', 1],
#   ['PLANET making progress', 1],
#   ['making progress commit', 1],
#   ['progress commit processing', 1],
#   ['optimization cloud data', 1],
#   ['cloud data market', 1]],
#  '2002': [['GEA toolkit gene', 1],
#   ['toolkit gene expression', 1],
#   ['gene expression analysis', 1],
#   ['StatiX making count', 1],
#   ['search engine retrieval', 1],
#   ['QURSED querying reporting', 1],
#   ['flavor query processing', 1],
#   ['decision support level', 1],
#   ['APEX path index', 1],
#   ['management service quality', 1]],
#  '2005': [['XML database management', 2],
#   ['processing oracle database', 1],
#   ['Enterprise information integration', 1],
#   ['Impact enterprise information', 1],
#   ['operation stream processing', 1],
#   ['stream processing engine', 1],
#   ['Fault-tolerance stream processing', 1],
#   ['stream processing system', 1],
#   ['XQBE environment query', 1],
#   ['Research protein location', 1]],
#  '2017': [['check web application', 1],
#   ['web application emergency', 1],
#   ['application emergency management', 1],
#   ['contexts geotagging trafficking', 1],
#   ['graph approach pre-processing', 1],
#   ['approach dimension web', 1],
#   ['Entity relationship affinity', 1],
#   ['web power data', 1],
#   ['power data repository', 1],
#   ['DEX Execution Storage', 1]],
#  '2006': [['integration transform reuse', 1],
#   ['transform reuse project', 1],
#   ['InMAF indexing music', 1],
#   ['VizQL language query', 1],
#   ['language query analysis', 1],
#   ['query analysis visualization', 1],
#   ['PADS system ad', 1],
#   ['system ad hoc', 1],
#   ['ranking database optimization', 1],
#   ['oracle database hub', 1]],
#  '2007': [['Sonnet dissemination broker', 1],
#   ['Storage workload estimation', 1],
#   ['workload estimation database', 1],
#   ['estimation database management', 1],
#   ['Spark keyword query', 1],
#   ['JouleSort energy-efficiency benchmark', 1],
#   ['K-relevance spectrum relevance', 1],
#   ['spectrum relevance query', 1],
#   ['InfiniteDB pc-cluster database', 1],
#   ['pc-cluster database management', 1]],
#  '2016': [['QUEPA QUerying Polystore', 1],
#   ['classification process reasoning', 1],
#   ['CourseNavigator path exploration', 1],
#   ['GeoSocialBound framework information', 1],
#   ['augmenting toponym disambiguation', 1],
#   ['toponym disambiguation similarity', 1],
#   ['gap intention model', 1],
#   ['discovery position paper', 1],
#   ['infrastructure vulnerability analysis', 1],
#   ['vulnerability analysis system', 1]],
#  '2023': [['Demonstration Provenance Extraction', 1]],
#  '2001': [['Snowball Prototype System', 1]],
#  '2022': [['HumanAL calibrating task', 1],
#   ['quest framework classification', 1],
#   ['LSI index structure', 1],
#   ['annotation tool scene', 1],
#   ['Neuroshard sharding reinforcement', 1],
#   ['sharding reinforcement learning', 1],
#   ['X-SSD Storage System', 1],
#   ['sight model understanding', 1],
#   ['model understanding context', 1],
#   ['Machop entity framework', 1]],
#  '2009': [['communication cost maintenance', 1],
#   ['path neighbor road', 1],
#   ['string compression memory', 1],
#   ['compression memory column', 1],
#   ['Storage class memory', 1],
#   ['class memory technology', 1],
#   ['control aqualogic platform', 1],
#   ['entity extraction edit', 1],
#   ['extraction edit distance', 1],
#   ['query processing document', 1]],
#  '2015': [['Purity Building Storage', 1],
#   ['Throne Information Integration', 1]],
#  '2004': [['TOSS Extension TAX', 1],
#   ['aggregation network model', 1],
#   ['network model algorithms', 1],
#   ['integration business intelligence', 1]],
#  '1981': [['Information Database Derivability', 1]],
#  '2019': [['schema extraction knowledge', 1],
#   ['possibility trade network', 1],
#   ['OPaPi routing manufacturing', 1],
#   ['PgCuckoo Laying Plan', 1],
#   ['stLD link discovery', 1],
#   ['link discovery framework', 1],
#   ['UniAdapt adaption replication', 1],
#   ['learning entity resolution', 1],
#   ['entity resolution experience', 1],
#   ['resolution experience report', 1]],
#  '2010': [['fusion management collaboration', 1],
#   ['query scheduling database', 1],
#   ['GDR system repair', 1],
#   ['XQuery aqualogic platform', 1],
#   ['graph processing cloud', 1],
#   ['Mask system access', 1],
#   ['system access content', 1],
#   ['DCUBE discrimination discovery', 1],
#   ['database evolution schemas', 1],
#   ['access query language', 1]],
#  '2008': [['identity anonymization graphs', 1],
#   ['CRD co-clustering matrix', 1],
#   ['co-clustering matrix decomposition', 1],
#   ['reverse skyline search', 1],
#   ['user feedback dataspace', 1],
#   ['query optimization design', 1],
#   ['optimization design tuning', 1],
#   ['testing test automation', 1],
#   ['test automation case', 1],
#   ['automation case study', 1]],
#  '2012': [['Probase taxonomy text', 1],
#   ['taxonomy text understanding', 1],
#   ['TIRAMOLA nosql management', 1],
#   ['nosql management platform', 1],
#   ['STRUCT information query', 1],
#   ['information query search', 1],
#   ['VRRC web tool', 1],
#   ['web tool visualization', 1],
#   ['tool visualization recommendation', 1],
#   ['visualization recommendation co-authorship', 1]],
#  '2000': [['javax.XXL prototype processing', 1]],
#  '2003': [['similarity search classification', 1],
#   ['search classification rank', 1],
#   ['classification rank aggregation', 1]],
#  '2011': [['Search computing search', 1],
#   ['computing search data', 1],
#   ['WINACS construction analysis', 1],
#   ['construction analysis computer', 1],
#   ['analysis computer science', 1],
#   ['computer science information', 1],
#   ['search engine corpus', 1],
#   ['engine corpus sampling', 1],
#   ['corpus sampling estimation', 1],
#   ['domain discovery web', 1]],
#  '1993': [['SIMS Retrieving Information', 1]],
#  '1977': [['Ulisse project terminal', 1],
#   ['project terminal system', 1],
#   ['Recovery Filing System', 1]],
#  '1985': [['ISIS Interface Information', 1]],
#  '1970': [['Storage pre-discussion summary', 1],
#   ['CODASYL Storage Storage', 1]]}

# %%
toptentrigramnouns['2023']
# Out:
# [['Demonstration Provenance Extraction', 1]]

# %%
print(ele.items())
for sub in ele:
    print(sub.tag)
    print(sub.text)

# %%
import hashlib

class Entity(object):
    def __init__(self) -> None:
        self.tag = ''
        self.relationships = dict()

    def __repr__(self) -> str:
        args = []
        for k, v in self.__dict__.items():
            args.append(str(k) + '=' + str(v))
        return 'Entity({args})'.format(
            args=','.join(args)
        )
    
    def __str__(self) -> str:
        return self.__repr__()
    
    @property
    def hash(self) -> str:
        return hashlib.sha256(self.__repr__().encode('utf-8')).hexdigest()

    def from_element(self, node: lxml.etree._Element) -> None:
        """
        Instantiates entity object with attributes from an Element object

        Parameters
        ----------
        node : lxml.etree._Element
        """
        self.tag = node.tag
        for attribute in node.items():
            setattr(self, attribute[0], attribute[1])

        for sub in node:
            self.relationships[sub.text] = sub.tag

# %%
from collections import defaultdict
i = 0
elements = []
all_elements = {'article', 'book', 'incollection', 'inproceedings'}
all_elements = 'article|inproceedings|proceedings|book|incollection|phdthesis|mastersthesis|www|person|data'.split('|')
all_entities = 'author|editor|title|booktitle|pages|year|address|journal|volume|number|month|url|ee|cdrom|cite|publisher|note|crossref|isbn|series|school|chapter|publnr|stream|rel'.split('|')
entities = []
entities_idx_by_tag = defaultdict(list)
entities_idx_by_key = defaultdict(lambda:defaultdict(list))

attributes_by_tag = defaultdict(lambda:defaultdict(int))
relationships_by_tag = defaultdict(lambda:defaultdict(int))

# %%
for _, element in dblp.data:

    if element.tag in (all_elements + all_entities):
        entity = Entity()
        entity.from_element(element)
        entities.append(entity)

        # index data
        entities_idx_by_tag[entity.tag].append(i)
        try:
            entities_idx_by_key[entity.tag][entity.key].append(i)
        except:
            entities_idx_by_key[entity.tag][entity.hash].append(i)

        # count attributes by tag
        for k, v in entity.__dict__.items():
            if k != 'relationships':
                
                attributes_by_tag[entity.tag][v] += 1

        for k, v in entity.relationships.items():
            relationships_by_tag[entity.tag][v] += 1

    element.clear()
    while element.getprevious() is not None:
        del element.getparent()[0]

    i += 1
    if i>10000:
        break

# %%
print(entities[4500])

# %%
entities = []

# %%
a = elements[4]
print(a)

# %%
a.items()

# %%
for sub in a:
    print(sub)
    print(a.tag)
